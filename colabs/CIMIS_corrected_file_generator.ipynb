# %% [markdown]
# <a href="https://colab.research.google.com/github/tr3nt-tayl0r/CIMIS/blob/main/CIMIS_corrected_file_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tr3nt-tayl0r/CIMIS.git
# Out:
# Cloning into 'CIMIS'...
# remote: Enumerating objects: 10857, done.
# remote: Counting objects: 100% (396/396), done.
# remote: Compressing objects: 100% (364/364), done.
# remote: Total 10857 (delta 35), reused 386 (delta 32), pack-reused 10461 (from 1)
# Receiving objects: 100% (10857/10857), 654.94 MiB | 9.96 MiB/s, done.
# Resolving deltas: 100% (2214/2214), done.
# Updating files: 100% (4030/4030), done.

# %%
import glob
import os
import sys
import datetime
import numpy as np
import pandas as pd
import json
import requests
import datetime
import matplotlib.pyplot as plt
from google.colab import userdata
# !pip install cartopy
import cartopy
import geopandas as gpd
# !pip install refet
import math
import refet
# Out:
# Collecting cartopy
#   Downloading Cartopy-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.7.1)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.0.5)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from cartopy) (24.1)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->cartopy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->cartopy) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->cartopy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->cartopy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.3.1->cartopy) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->cartopy) (1.16.0)
# Downloading Cartopy-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 83.1 MB/s eta 0:00:00
# Installing collected packages: cartopy
# Successfully installed cartopy-0.23.0
# Collecting refet
#   Downloading refet-0.4.2.tar.gz (27 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from refet) (1.26.4)
# Building wheels for collected packages: refet
#   Building wheel for refet (pyproject.toml) ... done
#   Created wheel for refet: filename=refet-0.4.2-py3-none-any.whl size=19274 sha256=dd079a90878f099ade8695f0f4fd5215e17483b3ddb1aaaf7897fa3694c4f936
#   Stored in directory: /root/.cache/pip/wheels/ab/55/da/7ed6e47f6fa1135fcdef373db6f974fd7515ee8e86c9662e88
# Successfully built refet
# Installing collected packages: refet
# Successfully installed refet-0.4.2

# %% [markdown]
# The following cell contains functions that are used in multiple places throughout the notebook. It contains a dictionary of changes ot the  column names. It also performs the temperature corrections that are used to generate the temperature-corrected files.

# %%
def fix_col_names(df):
  '''corrects column names from CIMIS based on dictionary'''
  rename_dict = {'DayAirTmpMin.Value':'Tmin',
               'DayAirTmpMin.Qc':'Tmin_Qc',
               'DayAirTmpMax.Value':'Tmax',
               'DayAirTmpMax.Qc':'Tmax_Qc',
               'DayDewPnt.Value':'Tdew',
               'DayDewPnt.Qc':'Tdew_Qc',
               'DayAirTmpAvg.Value':'Tavg',
               'DayAirTmpAvg.Qc':'Tavg_Qc',
               'DayEto.Value':'ETo',
               'DayEto.Qc':'ETo_Qc',
               'DayRelHumMin.Value':'RHmin',
               'DayRelHumMin.Qc':'RHmin_Qc',
               'DayRelHumMax.Value':'RHmax',
               'DayRelHumMax.Qc':'RHmax_Qc',
               'DayRelHumAvg.Value':'RHavg',
               'DayRelHumAvg.Qc':'RHavg_Qc',
               'DayPrecip.Value':'Pr',
               'DayPrecip.Qc':'Pr_Qc',
               'DaySolRadAvg.Value':'Rs',
               'DaySolRadAvg.Qc':'Rs_Qc',
               'DayVapPresAvg.Value':'Ea',
               'DayVapPresAvg.Qc':'Ea_Qc',
               'DayWindSpdAvg.Value':'u2',
               'DayWindSpdAvg.Qc':'u2_Qc',
               'Julian':'Doy'}
  df.rename(columns=rename_dict, inplace=True)
  return df

def corr_nref(df,tminNRef='Tmin',tdewNRef='Tdew',tmaxNRef='Tmax',bT=True):
    df['dT']=df[tminNRef]-df[tdewNRef]
    if bT==True:
        df['bT']=0.3
    dfAI = df[['Pr','ETo']].dropna(axis=0)
    AI = dfAI['Pr'].mean()/dfAI['ETo'].mean()
    print('\t\tAI = '+str(np.round(AI,2)))

    if AI < 0.05:
        aT=5
    elif (AI >= 0.05) & (AI < 0.2):
        aT=2.5
    elif (AI >= 0.2) & (AI < 0.5):
        aT=1.5
    elif (AI >= 0.5) & (AI < 0.65):
        aT=0.5
    else:
        aT=0

    df['aT']=aT

    #creates the columns for corrections, so that the keys exist for the next step
    df['Tmax_corr'] = 0.0
    df['Tmin_corr'] = 0.0
    df['Tdew_corr'] = 0.0

    # Might need to add a line only to correct if dT > aT from the logic statements above
    # TODO change this to use df.apply() instead of iterrows()
    for index, row in df.iterrows():
      if row['dT'] > aT:
        max_corr = row['Tmax'] - (row['bT']*(row['dT']-row['aT'])) #(2.13)
        df.loc[index, 'Tmax_corr'] = max_corr
        min_corr = row['Tmin'] - (row['bT']*(row['dT']-row['aT'])) #(2.14)
        df.loc[index, 'Tmin_corr'] = min_corr
        dew_corr = row['Tdew'] + ((1.0-row['bT'])*(row['dT']-row['aT'])) #(2.15)
        df.loc[index, 'Tdew_corr'] = dew_corr
      else:
        max = row['Tmax']
        df.loc[index, 'Tmax_corr'] = max
        min = row['Tmin']
        df.loc[index, 'Tmin_corr'] = min
        dew = row['Tdew']
        df.loc[index, 'Tdew_corr'] = dew
    df['AI']= AI
    # df.set_index(df.Date,inplace=True)
    return df

# %%
dir = '/content/CIMIS/stations/'
file = 'stations-meta.csv'

df = pd.read_csv(f'{dir}{file}')

station_ids = df['StationNbr'].tolist()

# %% [markdown]
# The following cell concatenates all of the files for each respective station into one MASTER file, which allows us to compute the long-term aridity index for each station.
#
# Because this cell concatenates each new file into any already-existing file, it is necessary to delete any existing MASTER file if an update needs to be made.

# %%
dir = "/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_raw_data/"

for id in station_ids:
  file = f'{dir}station{id}/station_id{id}_cimis_daily_raw_MASTER.csv'
  if(os.path.exists(file)):
    os.remove(file)
    print(f'station {id} MASTER file removed')

for id in station_ids:
  for year in range(2003,2025):
    file = f'{dir}station{id}/station_id{id}_cimis_daily_raw{year}.csv'
    #checks if file exists
    if os.path.exists(file):
      #checks if file is empty for years that a station was not active
      if os.stat(file).st_size > 1:
        df = pd.read_csv(file)

        #if a file already exists, it concatenates to that file, else creates it
        out_filename = f'{dir}station{id}/station_id{id}_cimis_daily_raw_MASTER.csv'
        if(os.path.exists(out_filename)):
          existing_df = pd.read_csv(out_filename)
          out_df = pd.concat([existing_df, df])
          out_df.to_csv(out_filename, index=False)
        else:
          df.to_csv(out_filename, index=False)
      else:
        continue
    else:
      continue
# Out:
# station 2 MASTER file removed
# station 6 MASTER file removed
# station 7 MASTER file removed
# station 12 MASTER file removed
# station 13 MASTER file removed
# station 15 MASTER file removed
# station 35 MASTER file removed
# station 39 MASTER file removed
# station 41 MASTER file removed
# station 43 MASTER file removed
# station 44 MASTER file removed
# station 47 MASTER file removed
# station 52 MASTER file removed
# station 64 MASTER file removed
# station 68 MASTER file removed
# station 70 MASTER file removed
# station 71 MASTER file removed
# station 75 MASTER file removed
# station 77 MASTER file removed
# station 78 MASTER file removed
# station 80 MASTER file removed
# station 83 MASTER file removed
# station 84 MASTER file removed
# station 87 MASTER file removed
# station 90 MASTER file removed
# station 91 MASTER file removed
# station 99 MASTER file removed
# station 103 MASTER file removed
# station 104 MASTER file removed
# station 105 MASTER file removed
# station 106 MASTER file removed
# station 107 MASTER file removed
# station 113 MASTER file removed
# station 114 MASTER file removed
# station 117 MASTER file removed
# station 124 MASTER file removed
# station 125 MASTER file removed
# station 126 MASTER file removed
# station 129 MASTER file removed
# station 131 MASTER file removed
# station 139 MASTER file removed
# station 140 MASTER file removed
# station 144 MASTER file removed
# station 146 MASTER file removed
# station 147 MASTER file removed
# station 150 MASTER file removed
# station 151 MASTER file removed
# station 152 MASTER file removed
# station 153 MASTER file removed
# station 157 MASTER file removed
# station 158 MASTER file removed
# station 160 MASTER file removed
# station 163 MASTER file removed
# station 165 MASTER file removed
# station 170 MASTER file removed
# station 171 MASTER file removed
# station 173 MASTER file removed
# station 174 MASTER file removed
# station 175 MASTER file removed
# station 178 MASTER file removed
# station 179 MASTER file removed
# station 181 MASTER file removed
# station 182 MASTER file removed
# station 184 MASTER file removed
# station 187 MASTER file removed
# station 191 MASTER file removed
# station 192 MASTER file removed
# station 193 MASTER file removed
# station 194 MASTER file removed
# station 195 MASTER file removed
# station 197 MASTER file removed
# station 199 MASTER file removed
# station 200 MASTER file removed
# station 202 MASTER file removed
# station 204 MASTER file removed
# station 206 MASTER file removed
# station 207 MASTER file removed
# station 208 MASTER file removed
# station 209 MASTER file removed
# station 210 MASTER file removed
# station 212 MASTER file removed
# station 213 MASTER file removed
# station 214 MASTER file removed
# station 215 MASTER file removed
# station 216 MASTER file removed
# station 217 MASTER file removed
# station 218 MASTER file removed
# station 219 MASTER file removed
# station 220 MASTER file removed
# station 221 MASTER file removed
# station 222 MASTER file removed
# station 223 MASTER file removed
# station 224 MASTER file removed
# station 225 MASTER file removed
# station 226 MASTER file removed
# station 227 MASTER file removed
# station 228 MASTER file removed
# station 229 MASTER file removed
# station 235 MASTER file removed
# station 236 MASTER file removed
# station 237 MASTER file removed
# station 240 MASTER file removed
# station 241 MASTER file removed
# station 242 MASTER file removed
# station 243 MASTER file removed
# station 244 MASTER file removed
# station 245 MASTER file removed
# station 246 MASTER file removed
# station 247 MASTER file removed
# station 248 MASTER file removed
# station 249 MASTER file removed
# station 250 MASTER file removed
# station 251 MASTER file removed
# station 252 MASTER file removed
# station 253 MASTER file removed
# station 254 MASTER file removed
# station 256 MASTER file removed
# station 258 MASTER file removed
# station 259 MASTER file removed
# station 260 MASTER file removed
# station 261 MASTER file removed
# station 262 MASTER file removed
# station 263 MASTER file removed
# station 264 MASTER file removed
# station 265 MASTER file removed
# station 266 MASTER file removed
# station 267 MASTER file removed
# station 268 MASTER file removed

# %% [markdown]
# This cell replaces any value in Tmax, Tmin, Tdew, Rs, Pr, or ETo that has a quality flag associated with it and converts the value to np.nan. It then calcuates what percentage of values for each variable is np.nan and stores that percentage in the stations-meta.csv as a new column.

# %%
st_dir = '/content/CIMIS/stations/'
st_file = 'stations-meta.csv'
st_df = pd.read_csv(f'{st_dir}{st_file}')

dir = '/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_raw_data/'

eto_flags = ['H', 'R']
pr_flags = ['H', 'R', 'S']
temp_flags = ['R', 'S', 'Y']
dew_flags = ['I', 'Q', 'Y']
solar_flags = ['H', 'R', 'S']

for id in station_ids:
  file = f'station{id}/station_id{id}_cimis_daily_raw_MASTER.csv'
  df = pd.read_csv(f'{dir}{file}')

  df.loc[df['ETo_Qc'].isin(eto_flags), 'ETo'] = np.nan
  df.loc[df['Pr_Qc'].isin(pr_flags), 'Pr'] = np.nan
  df.loc[df['Rs_Qc'].isin(solar_flags), 'Rs'] = np.nan
  df.loc[df['Tmax_Qc'].isin(temp_flags), 'Tmax'] = np.nan
  df.loc[df['Tmin_Qc'].isin(temp_flags), 'Tmin'] = np.nan
  df.loc[df['Tdew_Qc'].isin(dew_flags), 'Tdew'] = np.nan

  df.to_csv(f'{dir}{file}', index=False)
  df['Date']=pd.to_datetime(df['Date'])
  df.set_index(pd.to_datetime(df.Date), inplace=True)

  df_mjjas = df[(df['Date'].dt.month == 5) | (df['Date'].dt.month == 6) | (df['Date'].dt.month == 7) | (df['Date'].dt.month == 8) | (df['Date'].dt.month == 9)]
  denom = df_mjjas.shape[0]

  eto_num = df_mjjas['ETo'].isna().sum()
  eto_frac = 1 - eto_num/denom
  st_df.loc[st_df['StationNbr'] == id, 'ETo_Qc_fraction'] = eto_frac

  pr_num = df_mjjas['Pr'].isna().sum()
  pr_frac = 1 - pr_num/denom
  st_df.loc[st_df['StationNbr'] == id, 'Pr_Qc_fraction'] = pr_frac

  rs_num = df_mjjas['Rs'].isna().sum()
  rs_frac = 1 - rs_num/denom
  st_df.loc[st_df['StationNbr'] == id, 'Rs_Qc_fraction'] = rs_frac

  tmax_num = df_mjjas['Tmax'].isna().sum()
  tmax_frac = 1 - tmax_num/denom
  st_df.loc[st_df['StationNbr'] == id, 'Tmax_Qc_fraction'] = tmax_frac

  tmin_num = df_mjjas['Tmin'].isna().sum()
  tmin_frac = 1 - tmin_num/denom
  st_df.loc[st_df['StationNbr'] == id, 'Tmin_Qc_fraction'] = tmin_frac

  tdew_num = df_mjjas['Tdew'].isna().sum()
  tdew_frac = 1 - tdew_num/denom
  st_df.loc[st_df['StationNbr'] == id, 'Tdew_Qc_fraction'] = tdew_frac

print(st_df[['StationNbr','ETo_Qc_fraction', 'Pr_Qc_fraction', 'Rs_Qc_fraction', 'Tmax_Qc_fraction', 'Tmin_Qc_fraction', 'Tdew_Qc_fraction']])
st_df.to_csv(f'{st_dir}{st_file}', index=False)
# Out:
#      StationNbr  ETo_Qc_fraction  Pr_Qc_fraction  Rs_Qc_fraction  \
# 0             2         0.977162        0.984166        0.919915
# 1             6         0.980816        0.986906        0.961328
# 2             7         0.898295        0.982643        0.809988
# 3            12         0.935140        0.989647        0.966200
# 4            13         0.970463        0.989951        0.947016
# ..          ...              ...             ...             ...
# 123         264         0.939623        0.990566        0.981132
# 124         265         0.984085        0.994695        0.907162
# 125         266         0.961131        0.985866        0.883392
# 126         267         0.970822        0.938992        0.925729
# 127         268         1.000000        0.971831        0.943662
#
#      Tmax_Qc_fraction  Tmin_Qc_fraction  Tdew_Qc_fraction
# 0            0.968027          0.952497          0.950061
# 1            0.969549          0.944275          0.931486
# 2            0.959501          0.941230          0.936358
# 3            0.963459          0.943666          0.945189
# 4            0.915956          0.919610          0.899513
# ..                ...               ...               ...
# 123          0.956604          0.879245          0.903774
# 124          0.962865          0.952255          0.907162
# 125          0.943463          0.922261          0.893993
# 126          0.946950          0.952255          0.872679
# 127          0.971831          0.971831          0.985915
#
# [128 rows x 7 columns]

# %% [markdown]
# The following cell is used to create a dictionary of Aridity Index (AI) anomalies per year, and this is used ot remove stations from the station_ids global variable if a given station has an anomaly for more than 3 years.

# %%
import pprint

dir = '/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_raw_data/'
anomalies = []
anom_dict = {}

for id in station_ids:
  file = f'{dir}station{id}/station_id{id}_cimis_daily_raw_MASTER.csv'
  df = pd.read_csv(file)
  df['Date'] = pd.to_datetime(df.Date)
  df.set_index(pd.to_datetime(df.Date),inplace=True)
  for year in range(2003,2025):
    df_yr = df[(df['Date'].dt.year == year)]
    if not df_yr.empty:
      dfAI = df_yr[['Pr','ETo']].dropna(axis=0)
      AI = dfAI['Pr'].mean()/dfAI['ETo'].mean()
      if not ((AI >= 0.0) & (AI <= 1.0)):
        datum = (id, year, np.round(AI,2))
        anomalies.append(datum)
        if id not in anom_dict:
          anom_dict[id] = [(year, np.round(AI,2))]
        else:
          years = anom_dict.get(id)
          years.append((year, np.round(AI,2)))
          anom_dict[id] = years
      else:
        continue
    else:
      continue

station_anom = anom_dict.keys()
print(anomalies)
print()
print(station_anom)
print(len(station_anom))

pprint.pprint(anom_dict)
print(len(anom_dict))

to_remove = []
for st in station_anom:
  anoms = anom_dict.get(st)
  if len(anoms) > 3:
    to_remove.append(st)

# removes stations that have greater than 3 anomalous AI yrs
station_ids = [st for st in station_ids if st not in to_remove]
print(to_remove)
print(station_ids)
print(len(station_ids))
# Out:
#  262: [(2019, nan)],
#  263: [(2019, nan),
#        (2020, 3.82),
#        (2021, 1.73),
#        (2022, 1.46),
#        (2023, 2.96),
#        (2024, 3.78)],
#  264: [(2019, nan)]}
# 29
# [103, 139, 224, 246, 263]
# [2, 6, 7, 12, 13, 15, 35, 39, 41, 43, 44, 47, 52, 64, 68, 70, 71, 75, 77, 78, 80, 83, 84, 87, 90, 91, 99, 104, 105, 106, 107, 113, 114, 117, 124, 125, 126, 129, 131, 140, 144, 146, 147, 150, 151, 152, 153, 157, 158, 160, 163, 165, 170, 171, 173, 174, 175, 178, 179, 181, 182, 184, 187, 191, 192, 193, 194, 195, 197, 199, 200, 202, 204, 206, 207, 208, 209, 210, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 225, 226, 227, 228, 229, 235, 236, 237, 240, 241, 242, 243, 244, 245, 247, 248, 249, 250, 251, 252, 253, 254, 256, 258, 259, 260, 261, 262, 264, 265, 266, 267, 268]
# 123

# %% [markdown]
# The following cell is used to commit the raw files to GitHub after all necessary columns have been added to the csv files.

# %%
#the following line allows you to skip this cell for a RUN ALL execution without saving to GitHub
# %%script false --no-raise-error

if os.getcwd() != '/content/CIMIS':
  os.chdir("CIMIS")
token = userdata.get('github_token')
# !git --version
# !git config --global user.email "tretaylor@csumb.edu"
# !git config --global user.name "tr3nt-tayl0r"
# !git add -A
# !git commit -m "Commiting raw files"
# !git remote rm origin
# !git remote add origin https://tr3nt-tayl0r:{token}@github.com/tr3nt-tayl0r/CIMIS.git
# !git push --set-upstream origin main

# %% [markdown]
# The following cell takes each MASTER raw file as input in order to perform the temperature corrections and creates the corrected files. These temperature corrections are used to more accurately compute ETo on days when the difference between the min temp and the dew point temp is greater than alpha-T, which is computed from the aridity index. This cell also calculates the average monthly difference between the observed temperatures and the corrected temperatures.

# %%
import shutil
if os.getcwd() != '/content/CIMIS':
  os.chdir("CIMIS")
dir = "/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/"
shutil.rmtree(dir)
os.makedirs(dir)

for id in station_ids:
  filename = f'/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_raw_data/station{id}/station_id{id}_cimis_daily_raw_MASTER.csv'

  #checks if file exists
  if os.path.exists(filename):
    #checks if file is empty for years that a station was not active
    if os.stat(filename).st_size > 1:
      df_station = pd.read_csv(filename)

      #Switching 'Date' to the python datetime
      df_station['Date']=pd.to_datetime(df_station['Date'])
      df_station.set_index(pd.to_datetime(df_station.Date), inplace=True)

      print(id)
      df_station = corr_nref(df_station)

      df_station['Tmax_diff'] = df_station['Tmax'] - df_station['Tmax_corr']
      df_station['Tmin_diff'] = df_station['Tmin'] -  df_station['Tmin_corr']
      df_station['Tdew_diff'] = df_station['Tdew'] - df_station['Tdew_corr']

      df_station['Tmax_diff_avg'] = df_station['Tmax_diff'].groupby(pd.Grouper(axis=0, freq='M')).mean()
      df_station['Tmin_diff_avg'] = df_station['Tmin_diff'].groupby(pd.Grouper(axis=0, freq='M')).mean()
      df_station['Tdew_diff_avg'] = df_station['Tdew_diff'].groupby(pd.Grouper(axis=0, freq='M')).mean()

      #if a corrected file already exists, it concatenates to that file, else creates it
      out_filename = f'/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id{id}_cimis_daily_corr.csv'
      if(os.path.exists(out_filename)):
        existing_df = pd.read_csv(out_filename)
        out_df = pd.concat([existing_df, df_station])
        out_df.to_csv(out_filename, index=False)
      else:
        df_station.to_csv(out_filename, index=False)
    else:
      continue
  else:
    continue
# Out:
# 2
# 		AI = 0.13
# 6
# 		AI = 0.29
# 7
# 		AI = 0.12
# 12
# 		AI = 0.4
# 13
# 		AI = 0.56
# 15
# 		AI = 0.09
# 35
# 		AI = 0.08
# 39
# 		AI = 0.17
# 41
# 		AI = 0.02
# 43
# 		AI = 0.33
# 44
# 		AI = 0.14
# 47
# 		AI = 0.15
# 52
# 		AI = 0.37
# 64
# 		AI = 0.25
# 68
# 		AI = 0.02
# 70
# 		AI = 0.21
# 71
# 		AI = 0.17
# 75
# 		AI = 0.14
# 77
# 		AI = 0.28
# 78
# 		AI = 0.29
# 80
# 		AI = 0.18
# 83
# 		AI = 0.62
# 84
# 		AI = 0.39
# 87
# 		AI = 0.02
# 90
# 		AI = 0.21
# 91
# 		AI = 0.18
# 99
# 		AI = 0.23
# 104
# 		AI = 0.39
# 105
# 		AI = 0.08
# 106
# 		AI = 0.6
# 107
# 		AI = 0.36
# 113
# 		AI = 0.18
# 114
# 		AI = 0.15
# 117
# 		AI = 0.09
# 124
# 		AI = 0.1
# 125
# 		AI = 0.13
# 126
# 		AI = 0.24
# 129
# 		AI = 0.23
# 131
# 		AI = 0.39
# 140
# 		AI = 0.21
# 144
# 		AI = 0.49
# 146
# 		AI = 0.08
# 147
# 		AI = 0.18
# 150
# 		AI = 0.25
# 151
# 		AI = 0.03
# 152
# 		AI = 0.23
# 153
# 		AI = 0.2
# 157
# 		AI = 0.43
# 158
# 		AI = 0.57
# 160
# 		AI = 0.25
# 163
# 		AI = 0.24
# 165
# 		AI = 0.24
# 170
# 		AI = 0.29
# 171
# 		AI = 0.23
# 173
# 		AI = 0.26
# 174
# 		AI = 0.21
# 175
# 		AI = 0.02
# 178
# 		AI = 0.65
# 179
# 		AI = 0.13
# 181
# 		AI = 0.02
# 182
# 		AI = 0.12
# 184
# 		AI = 0.21
# 187
# 		AI = 0.48
# 191
# 		AI = 0.34
# 192
# 		AI = 0.33
# 193
# 		AI = 0.36
# 194
# 		AI = 0.23
# 195
# 		AI = 0.48
# 197
# 		AI = 0.06
# 199
# 		AI = 0.12
# 200
# 		AI = 0.01
# 202
# 		AI = 0.31
# 204
# 		AI = 0.14
# 206
# 		AI = 0.19
# 207
# 		AI = 0.03
# 208
# 		AI = 0.02
# 209
# 		AI = 0.48
# 210
# 		AI = 0.44
# 212
# 		AI = 0.43
# 213
# 		AI = 0.53
# 214
# 		AI = 0.22
# 215
# 		AI = 0.29
# 216
# 		AI = 0.12
# 217
# 		AI = 0.39
# 218
# 		AI = 0.01
# 219
# 		AI = 0.15
# 220
# 		AI = 0.09
# 221
# 		AI = 0.02
# 222
# 		AI = 0.27
# 223
# 		AI = 0.23
# 225
# 		AI = 0.29
# 226
# 		AI = 0.22
# 227
# 		AI = 0.58
# 228
# 		AI = 0.42
# 229
# 		AI = 0.42
# 235
# 		AI = 0.27
# 236
# 		AI = 0.3
# 237
# 		AI = 0.17
# 240
# 		AI = 0.1
# 241
# 		AI = 0.31
# 242
# 		AI = 0.3
# 243
# 		AI = 0.28
# 244
# 		AI = 0.3
# 245
# 		AI = 0.33
# 247
# 		AI = 0.22
# 248
# 		AI = 0.19
# 249
# 		AI = 0.19
# 250
# 		AI = 0.22
# 251
# 		AI = 0.29
# 252
# 		AI = 0.18
# 253
# 		AI = 0.56
# 254
# 		AI = 0.47
# 256
# 		AI = 0.07
# 258
# 		AI = 0.23
# 259
# 		AI = 0.95
# 260
# 		AI = 0.2
# 261
# 		AI = 0.15
# 262
# 		AI = 0.3
# 264
# 		AI = 0.21
# 265
# 		AI = 0.28
# 266
# 		AI = 0.27
# 267
# 		AI = 0.39
# 268
# 		AI = 0.34

# %% [markdown]
# The following cell calculates uncorrected and corrected ETo values for each day for each respective station using the RefET package and stores them in the temp-corrected file for that station.

# %%
dir = '/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/'

units={'tmin': 'C', 'tmax': 'C', 'tdew': 'C', 'rs': 'w/m2',
                 'uz': 'm/s', 'lat': 'deg'}

def calc_et_uncorr(row):
  eto_uncor = refet.Daily(
    tmin=row['Tmin'], tmax=row['Tmax'], tdew=row['Tdew'], rs=float(row['Rs']), uz=row['u2'],
    zw=2, elev=row['Elev'], lat=row['Lat'], doy=row['Doy'], method='asce',
    input_units=units).eto()
  return eto_uncor[0]

def calc_et_corr(row):
  eto_corr = refet.Daily(
    tmin=row['Tmin_corr'], tmax=row['Tmax_corr'], tdew=row['Tdew_corr'], rs=float(row['Rs']), uz=row['u2'],
    zw=2, elev=row['Elev'], lat=row['Lat'], doy=row['Doy'], method='asce',
    input_units=units).eto()
  return eto_corr[0]

for id in station_ids:
  file = f'{dir}station_id{id}_cimis_daily_corr.csv'
  if os.path.exists(file):
    df = pd.read_csv(file)

    df['ETo_uncor'] = df.apply(calc_et_uncorr, axis=1)
    df['ETo_corr'] = df.apply(calc_et_corr, axis=1)
    df['ETo_CIMIS'] = df['ETo']

    df.to_csv(file, index=False)

# %%
dir = '/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/'

for id in station_ids:
  file = f'station_id{id}_cimis_daily_corr.csv'
  df = pd.read_csv(f'{dir}{file}')
  denom = df.shape[0]
  print(f"Station {id}: ")

  corr = df['ETo_corr'].isna().sum()
  print(f'corrected eto nans: {corr}/{denom}={corr/denom}')

  uncor = df['ETo_uncor'].isna().sum()
  print(f'uncorrected eto nans: {uncor}/{denom}={uncor/denom}')
  print()
# Out:
# Station 2:
# corrected eto nans: 1107/7862=0.1408038667005851
# uncorrected eto nans: 1107/7862=0.1408038667005851
#
# Station 6:
# corrected eto nans: 966/7862=0.12286949885525311
# uncorrected eto nans: 966/7862=0.12286949885525311
#
# Station 7:
# corrected eto nans: 1624/7862=0.20656321546680234
# uncorrected eto nans: 1624/7862=0.20656321546680234
#
# Station 12:
# corrected eto nans: 1040/7862=0.13228186212159757
# uncorrected eto nans: 1040/7862=0.13228186212159757
#
# Station 13:
# corrected eto nans: 1394/7861=0.1773311283551711
# uncorrected eto nans: 1394/7861=0.1773311283551711
#
# Station 15:
# corrected eto nans: 1069/7862=0.13597049096921904
# uncorrected eto nans: 1069/7862=0.13597049096921904
#
# Station 35:
# corrected eto nans: 2109/7862=0.2682523530908166
# uncorrected eto nans: 2109/7862=0.2682523530908166
#
# Station 39:
# corrected eto nans: 1073/7862=0.1364792673619944
# uncorrected eto nans: 1073/7862=0.1364792673619944
#
# Station 41:
# corrected eto nans: 1972/7862=0.25082676163826
# uncorrected eto nans: 1972/7862=0.25082676163826
#
# Station 43:
# corrected eto nans: 1253/7862=0.1593742050368863
# uncorrected eto nans: 1253/7862=0.1593742050368863
#
# Station 44:
# corrected eto nans: 1462/7862=0.18595777155939963
# uncorrected eto nans: 1462/7862=0.18595777155939963
#
# Station 47:
# corrected eto nans: 1540/7674=0.20067761271826948
# uncorrected eto nans: 1540/7674=0.20067761271826948
#
# Station 52:
# corrected eto nans: 1029/7862=0.13088272704146528
# uncorrected eto nans: 1029/7862=0.13088272704146528
#
# Station 64:
# corrected eto nans: 1261/7862=0.16039175782243703
# uncorrected eto nans: 1261/7862=0.16039175782243703
#
# Station 68:
# corrected eto nans: 2169/7862=0.2758839989824472
# uncorrected eto nans: 2169/7862=0.2758839989824472
#
# Station 70:
# corrected eto nans: 810/7862=0.10302721953701348
# uncorrected eto nans: 810/7862=0.10302721953701348
#
# Station 71:
# corrected eto nans: 938/7862=0.11930806410582549
# uncorrected eto nans: 938/7862=0.11930806410582549
#
# Station 75:
# corrected eto nans: 1556/7862=0.19791401678962095
# uncorrected eto nans: 1556/7862=0.19791401678962095
#
# Station 77:
# corrected eto nans: 1327/7861=0.16880803968960692
# uncorrected eto nans: 1327/7861=0.16880803968960692
#
# Station 78:
# corrected eto nans: 1330/7862=0.16916815059781226
# uncorrected eto nans: 1330/7862=0.16916815059781226
#
# Station 80:
# corrected eto nans: 1585/7862=0.20160264563724242
# uncorrected eto nans: 1585/7862=0.20160264563724242
#
# Station 83:
# corrected eto nans: 1301/7862=0.1654795217501908
# uncorrected eto nans: 1301/7862=0.1654795217501908
#
# Station 84:
# corrected eto nans: 1095/7862=0.13927753752225897
# uncorrected eto nans: 1095/7862=0.13927753752225897
#
# Station 87:
# corrected eto nans: 1548/7862=0.1968964640040702
# uncorrected eto nans: 1548/7862=0.1968964640040702
#
# Station 90:
# corrected eto nans: 1247/7862=0.15861104044772323
# uncorrected eto nans: 1247/7862=0.15861104044772323
#
# Station 91:
# corrected eto nans: 790/7862=0.1004833375731366
# uncorrected eto nans: 790/7862=0.1004833375731366
#
# Station 99:
# corrected eto nans: 1403/7856=0.17858961303462323
# uncorrected eto nans: 1403/7856=0.17858961303462323
#
# Station 104:
# corrected eto nans: 1005/7862=0.12783006868481303
# uncorrected eto nans: 1005/7862=0.12783006868481303
#
# Station 105:
# corrected eto nans: 1325/7862=0.16853218010684304
# uncorrected eto nans: 1325/7862=0.16853218010684304
#
# Station 106:
# corrected eto nans: 1943/7862=0.2471381327906385
# uncorrected eto nans: 1943/7862=0.2471381327906385
#
# Station 107:
# corrected eto nans: 1564/7862=0.19893156957517172
# uncorrected eto nans: 1564/7862=0.19893156957517172
#
# Station 113:
# corrected eto nans: 1113/7862=0.14156703128974815
# uncorrected eto nans: 1113/7862=0.14156703128974815
#
# Station 114:
# corrected eto nans: 1343/7862=0.17082167387433222
# uncorrected eto nans: 1343/7862=0.17082167387433222
#
# Station 117:
# corrected eto nans: 1527/7862=0.19422538794199948
# uncorrected eto nans: 1527/7862=0.19422538794199948
#
# Station 124:
# corrected eto nans: 1172/7862=0.14907148308318494
# uncorrected eto nans: 1172/7862=0.14907148308318494
#
# Station 125:
# corrected eto nans: 436/3479=0.12532336878413336
# uncorrected eto nans: 436/3479=0.12532336878413336
#
# Station 126:
# corrected eto nans: 1159/7862=0.14741795980666497
# uncorrected eto nans: 1159/7862=0.14741795980666497
#
# Station 129:
# corrected eto nans: 1183/7862=0.15047061816331722
# uncorrected eto nans: 1183/7862=0.15047061816331722
#
# Station 131:
# corrected eto nans: 1002/7862=0.12744848639023149
# uncorrected eto nans: 1002/7862=0.12744848639023149
#
# Station 140:
# corrected eto nans: 1517/7862=0.19295344696006106
# uncorrected eto nans: 1517/7862=0.19295344696006106
#
# Station 144:
# corrected eto nans: 1212/7767=0.1560448049439938
# uncorrected eto nans: 1212/7767=0.1560448049439938
#
# Station 146:
# corrected eto nans: 1187/7862=0.1509793945560926
# uncorrected eto nans: 1187/7862=0.1509793945560926
#
# Station 147:
# corrected eto nans: 2369/7861=0.30136114998091845
# uncorrected eto nans: 2369/7861=0.30136114998091845
#
# Station 150:
# corrected eto nans: 1285/7862=0.16344441617908928
# uncorrected eto nans: 1285/7862=0.16344441617908928
#
# Station 151:
# corrected eto nans: 2327/7862=0.29598066649707455
# uncorrected eto nans: 2327/7862=0.29598066649707455
#
# Station 152:
# corrected eto nans: 1068/7862=0.13584329687102517
# uncorrected eto nans: 1068/7862=0.13584329687102517
#
# Station 153:
# corrected eto nans: 2182/7860=0.2776081424936387
# uncorrected eto nans: 2182/7860=0.2776081424936387
#
# Station 157:
# corrected eto nans: 1182/7862=0.15034342406512338
# uncorrected eto nans: 1182/7862=0.15034342406512338
#
# Station 158:
# corrected eto nans: 1485/7857=0.18900343642611683
# uncorrected eto nans: 1485/7857=0.18900343642611683
#
# Station 160:
# corrected eto nans: 1658/7854=0.21110262286732875
# uncorrected eto nans: 1658/7854=0.21110262286732875
#
# Station 163:
# corrected eto nans: 2484/7849=0.3164734361065104
# uncorrected eto nans: 2484/7849=0.3164734361065104
#
# Station 165:
# corrected eto nans: 1891/7858=0.24064647493000763
# uncorrected eto nans: 1891/7858=0.24064647493000763
#
# Station 170:
# corrected eto nans: 1449/7861=0.18432769367764915
# uncorrected eto nans: 1449/7861=0.18432769367764915
#
# Station 171:
# corrected eto nans: 1099/7862=0.13978631391503435
# uncorrected eto nans: 1099/7862=0.13978631391503435
#
# Station 173:
# corrected eto nans: 1330/7862=0.16916815059781226
# uncorrected eto nans: 1330/7862=0.16916815059781226
#
# Station 174:
# corrected eto nans: 1774/7861=0.22567103421956494
# uncorrected eto nans: 1774/7861=0.22567103421956494
#
# Station 175:
# corrected eto nans: 1902/7862=0.2419231747646909
# uncorrected eto nans: 1902/7862=0.2419231747646909
#
# Station 178:
# corrected eto nans: 2007/7862=0.25527855507504454
# uncorrected eto nans: 2007/7862=0.25527855507504454
#
# Station 179:
# corrected eto nans: 2761/7861=0.3512275791883984
# uncorrected eto nans: 2761/7861=0.3512275791883984
#
# Station 181:
# corrected eto nans: 1584/7275=0.2177319587628866
# uncorrected eto nans: 1584/7275=0.2177319587628866
#
# Station 182:
# corrected eto nans: 1487/7862=0.18913762401424575
# uncorrected eto nans: 1487/7862=0.18913762401424575
#
# Station 184:
# corrected eto nans: 1777/7862=0.22602391249046044
# uncorrected eto nans: 1777/7862=0.22602391249046044
#
# Station 187:
# corrected eto nans: 1478/7697=0.19202286605170846
# uncorrected eto nans: 1478/7697=0.19202286605170846
#
# Station 191:
# corrected eto nans: 1432/7386=0.19388031410777146
# uncorrected eto nans: 1432/7386=0.19388031410777146
#
# Station 192:
# corrected eto nans: 2244/7422=0.30234438156831045
# uncorrected eto nans: 2244/7422=0.30234438156831045
#
# Station 193:
# corrected eto nans: 917/4642=0.1975441619991383
# uncorrected eto nans: 917/4642=0.1975441619991383
#
# Station 194:
# corrected eto nans: 1132/7191=0.1574189959671812
# uncorrected eto nans: 1132/7191=0.1574189959671812
#
# Station 195:
# corrected eto nans: 1269/7088=0.17903498871331827
# uncorrected eto nans: 1269/7088=0.17903498871331827
#
# Station 197:
# corrected eto nans: 1465/7036=0.20821489482660602
# uncorrected eto nans: 1465/7036=0.20821489482660602
#
# Station 199:
# corrected eto nans: 2141/6934=0.30876838765503317
# uncorrected eto nans: 2141/6934=0.30876838765503317
#
# Station 200:
# corrected eto nans: 1697/6630=0.2559577677224736
# uncorrected eto nans: 1697/6630=0.2559577677224736
#
# Station 202:
# corrected eto nans: 1204/6589=0.18272879040825618
# uncorrected eto nans: 1204/6589=0.18272879040825618
#
# Station 204:
# corrected eto nans: 1756/6422=0.27343506695733416
# uncorrected eto nans: 1756/6422=0.27343506695733416
#
# Station 206:
# corrected eto nans: 1161/5572=0.2083632447954056
# uncorrected eto nans: 1161/5572=0.2083632447954056
#
# Station 207:
# corrected eto nans: 2394/6018=0.39780658025922233
# uncorrected eto nans: 2394/6018=0.39780658025922233
#
# Station 208:
# corrected eto nans: 1820/6271=0.2902248445224047
# uncorrected eto nans: 1820/6271=0.2902248445224047
#
# Station 209:
# corrected eto nans: 1243/6238=0.19926258416159026
# uncorrected eto nans: 1243/6238=0.19926258416159026
#
# Station 210:
# corrected eto nans: 1200/5739=0.20909566126502874
# uncorrected eto nans: 1200/5739=0.20909566126502874
#
# Station 212:
# corrected eto nans: 1214/5381=0.22560862293254041
# uncorrected eto nans: 1214/5381=0.22560862293254041
#
# Station 213:
# corrected eto nans: 702/3885=0.1806949806949807
# uncorrected eto nans: 702/3885=0.1806949806949807
#
# Station 214:
# corrected eto nans: 707/4073=0.17358212619690647
# uncorrected eto nans: 707/4073=0.17358212619690647
#
# Station 215:
# corrected eto nans: 1319/4691=0.28117672138136857
# uncorrected eto nans: 1319/4691=0.28117672138136857
#
# Station 216:
# corrected eto nans: 1431/4690=0.3051172707889126
# uncorrected eto nans: 1431/4690=0.3051172707889126
#
# Station 217:
# corrected eto nans: 804/3661=0.21961212783392517
# uncorrected eto nans: 804/3661=0.21961212783392517
#
# Station 218:
# corrected eto nans: 1176/5275=0.22293838862559243
# uncorrected eto nans: 1176/5275=0.22293838862559243
#
# Station 219:
# corrected eto nans: 1098/4691=0.23406523129396717
# uncorrected eto nans: 1098/4691=0.23406523129396717
#
# Station 220:
# corrected eto nans: 1050/4859=0.21609384647046717
# uncorrected eto nans: 1050/4859=0.21609384647046717
#
# Station 221:
# corrected eto nans: 2116/5002=0.423030787684926
# uncorrected eto nans: 2116/5002=0.423030787684926
#
# Station 222:
# corrected eto nans: 938/3619=0.25918762088974856
# uncorrected eto nans: 938/3619=0.25918762088974856
#
# Station 223:
# corrected eto nans: 806/2551=0.3159545276362211
# uncorrected eto nans: 806/2551=0.3159545276362211
#
# Station 225:
# corrected eto nans: 500/3370=0.14836795252225518
# uncorrected eto nans: 500/3370=0.14836795252225518
#
# Station 226:
# corrected eto nans: 737/4811=0.15319060486385366
# uncorrected eto nans: 737/4811=0.15319060486385366
#
# Station 227:
# corrected eto nans: 913/4999=0.1826365273054611
# uncorrected eto nans: 913/4999=0.1826365273054611
#
# Station 228:
# corrected eto nans: 1126/5034=0.22367898291617005
# uncorrected eto nans: 1126/5034=0.22367898291617005
#
# Station 229:
# corrected eto nans: 1085/4643=0.23368511738100367
# uncorrected eto nans: 1085/4643=0.23368511738100367
#
# Station 235:
# corrected eto nans: 728/4436=0.16411181244364292
# uncorrected eto nans: 728/4436=0.16411181244364292
#
# Station 236:
# corrected eto nans: 607/3373=0.17995849392232435
# uncorrected eto nans: 607/3373=0.17995849392232435
#
# Station 237:
# corrected eto nans: 1333/4278=0.3115942028985507
# uncorrected eto nans: 1333/4278=0.3115942028985507
#
# Station 240:
# corrected eto nans: 694/4065=0.17072570725707256
# uncorrected eto nans: 694/4065=0.17072570725707256
#
# Station 241:
# corrected eto nans: 662/3288=0.201338199513382
# uncorrected eto nans: 662/3288=0.201338199513382
#
# Station 242:
# corrected eto nans: 792/3170=0.24984227129337538
# uncorrected eto nans: 792/3170=0.24984227129337538
#
# Station 243:
# corrected eto nans: 603/3128=0.19277493606138107
# uncorrected eto nans: 603/3128=0.19277493606138107
#
# Station 244:
# corrected eto nans: 759/3310=0.22930513595166163
# uncorrected eto nans: 759/3310=0.22930513595166163
#
# Station 245:
# corrected eto nans: 854/3199=0.26695842450765866
# uncorrected eto nans: 854/3199=0.26695842450765866
#
# Station 247:
# corrected eto nans: 1204/2931=0.4107813033094507
# uncorrected eto nans: 1204/2931=0.4107813033094507
#
# Station 248:
# corrected eto nans: 492/2931=0.16786079836233367
# uncorrected eto nans: 492/2931=0.16786079836233367
#
# Station 249:
# corrected eto nans: 995/2931=0.3394745820539065
# uncorrected eto nans: 995/2931=0.3394745820539065
#
# Station 250:
# corrected eto nans: 737/2892=0.2548409405255878
# uncorrected eto nans: 737/2892=0.2548409405255878
#
# Station 251:
# corrected eto nans: 473/2830=0.16713780918727916
# uncorrected eto nans: 473/2830=0.16713780918727916
#
# Station 252:
# corrected eto nans: 434/2868=0.15132496513249652
# uncorrected eto nans: 434/2868=0.15132496513249652
#
# Station 253:
# corrected eto nans: 556/2517=0.2208978943186333
# uncorrected eto nans: 556/2517=0.2208978943186333
#
# Station 254:
# corrected eto nans: 458/2318=0.19758412424503882
# uncorrected eto nans: 458/2318=0.19758412424503882
#
# Station 256:
# corrected eto nans: 1009/2176=0.46369485294117646
# uncorrected eto nans: 1009/2176=0.46369485294117646
#
# Station 258:
# corrected eto nans: 332/2063=0.16093068347067377
# uncorrected eto nans: 332/2063=0.16093068347067377
#
# Station 259:
# corrected eto nans: 493/1801=0.27373681288173235
# uncorrected eto nans: 493/1801=0.27373681288173235
#
# Station 260:
# corrected eto nans: 652/1755=0.3715099715099715
# uncorrected eto nans: 652/1755=0.3715099715099715
#
# Station 261:
# corrected eto nans: 347/1757=0.19749573136027318
# uncorrected eto nans: 347/1757=0.19749573136027318
#
# Station 262:
# corrected eto nans: 221/1597=0.13838447088290545
# uncorrected eto nans: 221/1597=0.13838447088290545
#
# Station 264:
# corrected eto nans: 266/1351=0.19689119170984457
# uncorrected eto nans: 266/1351=0.19689119170984457
#
# Station 265:
# corrected eto nans: 163/846=0.19267139479905437
# uncorrected eto nans: 163/846=0.19267139479905437
#
# Station 266:
# corrected eto nans: 143/708=0.2019774011299435
# uncorrected eto nans: 143/708=0.2019774011299435
#
# Station 267:
# corrected eto nans: 170/806=0.2109181141439206
# uncorrected eto nans: 170/806=0.2109181141439206
#
# Station 268:
# corrected eto nans: 23/232=0.09913793103448276
# uncorrected eto nans: 23/232=0.09913793103448276

# %%
dir = '/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/'

stations = [2]

def process_nans(key_value):
  key, value = key_value
  if value >= 10:
    eto_nan_list.append((key, value))

for id in station_ids:
  file = f'station_id{id}_cimis_daily_corr.csv'
  df = pd.read_csv(f'{dir}{file}')
  df['Date'] = pd.to_datetime(df['Date'])
  df.set_index(pd.to_datetime(df.Date), inplace=True)
  df['month_year'] = df.index.to_period('M')  # Converts to Month-Year period

  eto_nan_list = []
  monthly_nan_counts = df.groupby('month_year')['ETo_uncor'].apply(lambda x: x.isna().sum())
  result_dict = monthly_nan_counts.rename(lambda x: x.strftime('%Y-%m')).to_dict()

  list(map(process_nans, result_dict.items()))

  denom = len(result_dict.keys())
  num = len(eto_nan_list)

  print(f'station {id}:')
  print(eto_nan_list)
  print(f'{num}/{denom} = {num/denom}')
  print()
# Out:
# station 2:
# [('2019-10', 13), ('2020-01', 31), ('2020-02', 29), ('2020-03', 31), ('2020-04', 30), ('2020-05', 31), ('2020-06', 30), ('2020-07', 31), ('2020-08', 31), ('2020-09', 30), ('2021-03', 10), ('2021-04', 15), ('2021-06', 14), ('2021-07', 22), ('2021-08', 14), ('2022-05', 11), ('2022-07', 13), ('2022-08', 27), ('2022-09', 14), ('2022-10', 13), ('2023-07', 13), ('2023-08', 11), ('2023-10', 12), ('2024-05', 10)]
# 24/59 = 0.4067796610169492
#
# station 261:
# [('2019-10', 13), ('2020-03', 10), ('2021-03', 14), ('2021-04', 17), ('2021-06', 12), ('2021-07', 12), ('2022-05', 14), ('2022-08', 13), ('2023-10', 10), ('2024-05', 14)]
# 10/59 = 0.1694915254237288
#
# station 262:
# [('2022-05', 13), ('2024-05', 11)]
# 2/55 = 0.03636363636363636
#
# station 264:
# [('2021-04', 10), ('2021-10', 10), ('2022-06', 11), ('2022-07', 10), ('2022-08', 10), ('2022-12', 12), ('2023-01', 14), ('2023-02', 16), ('2023-03', 14), ('2023-06', 10)]
# 10/47 = 0.2127659574468085
#
# station 265:
# [('2022-04', 13), ('2022-05', 20), ('2022-06', 13), ('2022-09', 12), ('2023-03', 11)]
# 5/29 = 0.1724137931034483
#
# station 266:
# [('2022-08', 11), ('2022-09', 15), ('2023-01', 11), ('2023-03', 10), ('2023-04', 16), ('2023-07', 10)]
# 6/24 = 0.25
#
# station 267:
# [('2022-05', 10), ('2022-06', 10), ('2022-10', 29), ('2022-11', 14), ('2023-03', 11), ('2023-08', 10)]
# 6/28 = 0.21428571428571427
#
# station 268:
# []
# 0/9 = 0.0

# %% [markdown]
# The following cell is used to append the NDVI timeseries data to the temperature-corrected dataframes.

# %%
from scipy.interpolate import UnivariateSpline

item_to_remove = 268
station_ids = [item for item in station_ids if item != item_to_remove]

print(station_ids)

ndvi_dir = "/content/CIMIS/CIMIS_Project_Data/NDVI_timeseries_data/"
df_dir = '/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/'

#station_ids = [2, 5, 6, 7, 12, 13, 15, 35, 39, 41, 43, 44, 47, 52, 62, 64, 68, 70, 71, 75, 77, 78, 80, 83, 84, 87, 88, 90, 91, 99, 103, 104, 105, 106, 107, 113, 114, 116, 117, 124, 125, 126, 129, 131, 135, 136, 139, 140, 143, 144, 146, 147, 148, 150, 151, 152, 153, 157, 158, 159, 160, 163, 165, 170, 171, 173, 174, 175, 178, 179, 181, 182, 183, 184, 187, 189, 191, 192, 193, 194, 195, 197, 199, 200, 202, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 231, 232, 233, 235, 236, 237, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267]
#this list of stations does not contain non-ETo stations or stations with significant anomalies
#station_ids = [2, 6, 7, 12, 13, 15, 35, 39, 41, 43, 44, 47, 52, 64, 68, 70, 75, 77, 78, 80, 83, 84, 87, 90, 91, 99, 104, 105, 106, 107, 113, 114, 117, 124, 125, 126, 129, 131, 136, 140, 144, 146, 147, 148, 150, 151, 152, 153, 157, 158, 160, 163, 165, 170, 171, 173, 174, 175, 178, 179, 181, 182, 184, 187, 191, 192, 193, 194, 195, 197, 199, 200, 202, 204, 206, 207, 208, 209, 210, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 225, 226, 227, 228, 229, 235, 236, 237, 240, 241, 242, 243, 244, 245, 247, 248, 249, 250, 251, 252, 253, 254, 256, 258, 259, 260, 261, 262, 264, 265, 266, 267, 268]


for id in station_ids:
  print(f'Station {id}:')
  ndvi_file = f"station_id{id}_ndvi.csv"
  ndvi_df = pd.read_csv(f'{ndvi_dir}{ndvi_file}')
  #ndvi_df = ndvi_df[ndvi_df.columns.drop(df.filter(regex='Average'))]

  cols_to_drop = ndvi_df.filter(regex='Average').columns
  ndvi_df = ndvi_df.drop(columns=cols_to_drop)

  ndvi_df.columns = ['Date', 'NDVI']
  ndvi_df['Date']=pd.to_datetime(ndvi_df['Date'])
  ndvi_df.set_index(pd.to_datetime(ndvi_df.Date), inplace=True)
  #print(ndvi_df.head())

  full_date_range = pd.date_range(start=ndvi_df.index.min(), end=ndvi_df.index.max(), freq='D')
  # Reindex the DataFrame to include all dates
  ndvi_df = ndvi_df.reindex(full_date_range)

  # do lin interp prior to rolling window
  ndvi_df['NDVI_interp'] = ndvi_df['NDVI'].interpolate(method='linear', limit=30, limit_direction='both')
  ndvi_df['NDVI_interp'] = ndvi_df['NDVI_interp'].rolling(window=64, min_periods=8, center=True).mean()  # window 15, min 7, to flag outliers
  print(ndvi_df.head(35))
  plt.plot(ndvi_df.index, ndvi_df['NDVI_interp'])

  file = f'station_id{id}_cimis_daily_corr.csv'
  df = pd.read_csv(f'{df_dir}{file}')
  df['Date']=pd.to_datetime(df['Date'])
  df.set_index(pd.to_datetime(df.Date), inplace=True)
  #df.drop(['Date_left', 'Date_right'], axis=1, inplace=True)
  #print(df.head())

  df_combined = df.join(ndvi_df, lsuffix='_left', rsuffix='_right')
  df_combined['Date'] = df_combined['Date_left']
  df_combined.drop(['Date_left', 'Date_right'], axis=1, inplace=True)
  df_combined['Date']=pd.to_datetime(df_combined['Date'])
  df_combined.set_index(pd.to_datetime(df_combined.Date), inplace=True)
  cols = ['Date'] + [col for col in df_combined.columns if col != 'Date']
  df_combined = df_combined[cols]
  print(df_combined.head())

  practice_file = f'station_id{id}_cimis_daily_corr_interp.csv'
  pract_dir = "/content/CIMIS/"
  df_combined.to_csv(f'{df_dir}{file}', index=False)

station_ids.append(268)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2003-02-10        NaT     NaN     0.790774
#                  Date  Doy  Station Standard  \
# Date
# 2003-01-01 2003-01-01    1      170   metric
# 2003-01-02 2003-01-02    2      170   metric
# 2003-01-03 2003-01-03    3      170   metric
# 2003-01-04 2003-01-04    4      170   metric
# 2003-01-05 2003-01-05    5      170   metric
#
#                                                      ZipCodes  Scope  Tavg  \
# Date
# 2003-01-01  94529, 94527, 94524, 94523, 94522, 94521, 9452...  daily   8.2
# 2003-01-02  94529, 94527, 94524, 94523, 94522, 94521, 9452...  daily   9.0
# 2003-01-03  94529, 94527, 94524, 94523, 94522, 94521, 9452...  daily   9.7
# 2003-01-04  94529, 94527, 94524, 94523, 94522, 94521, 9452...  daily  10.8
# 2003-01-05  94529, 94527, 94524, 94523, 94522, 94521, 9452...  daily  11.4
#
#            Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                              ...
# 2003-01-01          13.2          ...        0.0       0.0            NaN
# 2003-01-02          12.1          ...        0.0       0.0            NaN
# 2003-01-03          15.1          ...        0.0       0.0            NaN
# 2003-01-04          17.7          ...        0.0       0.0            NaN
# 2003-01-05          20.5          ...        0.0       0.0            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS  NDVI  \
# Date
# 2003-01-01           NaN            NaN  0.717307  0.717307      1.01   NaN
# 2003-01-02           NaN            NaN  0.640603  0.640603      0.53   NaN
# 2003-01-03           NaN            NaN  0.890695  0.890695      1.11   NaN
# 2003-01-04           NaN            NaN  0.899407  0.899407      1.17   NaN
# 2003-01-05           NaN            NaN  1.063473  1.063473      1.35   NaN
#
#            NDVI_interp
# Date
# 2003-01-01         NaN
# 2003-01-02         NaN
# 2003-01-03         NaN
# 2003-01-04         NaN
# 2003-01-05         NaN
#
# [5 rows x 55 columns]
# Station 171:
#                  Date    NDVI  NDVI_interp
# 2003-01-07 2003-01-07  0.7489     0.743158
# 2003-01-08        NaT     NaN     0.743535
# 2003-01-09        NaT     NaN     0.743522
# 2003-01-10        NaT     NaN     0.743154
# 2003-01-11        NaT     NaN     0.742459
# 2003-01-12        NaT     NaN     0.741464
# 2003-01-13        NaT     NaN     0.740193
# 2003-01-14        NaT     NaN     0.738667
# 2003-01-15 2003-01-15  0.7326     0.736905
# 2003-01-16        NaT     NaN     0.734924
# 2003-01-17        NaT     NaN     0.733077
# 2003-01-18        NaT     NaN     0.731353
# 2003-01-19        NaT     NaN     0.729745
# 2003-01-20        NaT     NaN     0.728245
# 2003-01-21        NaT     NaN     0.726845
# 2003-01-22        NaT     NaN     0.725539
# 2003-01-23        NaT     NaN     0.724322
# 2003-01-24        NaT     NaN     0.723188
# 2003-01-25        NaT     NaN     0.722132
# 2003-01-26        NaT     NaN     0.721149
# 2003-01-27        NaT     NaN     0.720236
# 2003-01-28        NaT     NaN     0.719388
# 2003-01-29        NaT     NaN     0.718601
# 2003-01-30        NaT     NaN     0.717872
# 2003-01-31        NaT     NaN     0.717199
# 2003-02-01        NaT     NaN     0.716578
# 2003-02-02        NaT     NaN     0.715971
# 2003-02-03        NaT     NaN     0.715376
# 2003-02-04        NaT     NaN     0.714794
# 2003-02-05        NaT     NaN     0.714224
# 2003-02-06        NaT     NaN     0.713665
# 2003-02-07        NaT     NaN     0.713116
# 2003-02-08 2003-02-08  0.7556     0.712577
# 2003-02-09        NaT     NaN     0.711473
# 2003-02-10        NaT     NaN     0.710393
#                  Date  Doy  Station Standard  \
# Date
# 2003-01-01 2003-01-01    1      171   metric
# 2003-01-02 2003-01-02    2      171   metric
# 2003-01-03 2003-01-03    3      171   metric
# 2003-01-04 2003-01-04    4      171   metric
# 2003-01-05 2003-01-05    5      171   metric
#
#                                                      ZipCodes  Scope  Tavg  \
# Date
# 2003-01-01  94536, 94537, 94538, 94539, 94555, 94587, 9454...  daily   7.9
# 2003-01-02  94536, 94537, 94538, 94539, 94555, 94587, 9454...  daily   9.4
# 2003-01-03  94536, 94537, 94538, 94539, 94555, 94587, 9454...  daily   9.7
# 2003-01-04  94536, 94537, 94538, 94539, 94555, 94587, 9454...  daily  10.9
# 2003-01-05  94536, 94537, 94538, 94539, 94555, 94587, 9454...  daily  10.5
#
#            Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                              ...
# 2003-01-01          14.5          ...        0.0       0.0            NaN
# 2003-01-02          14.8          ...        0.0       0.0            NaN
# 2003-01-03          16.5          ...        0.0       0.0            NaN
# 2003-01-04          17.3          ...        0.0       0.0            NaN
# 2003-01-05          17.1          ...        0.0       0.0            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS  NDVI  \
# Date
# 2003-01-01           NaN            NaN  0.732893  0.732893      1.21   NaN
# 2003-01-02           NaN            NaN  0.757059  0.757059      0.75   NaN
# 2003-01-03           NaN            NaN  0.917865  0.917865      1.10   NaN
# 2003-01-04           NaN            NaN  0.839793  0.839793      1.18   NaN
# 2003-01-05           NaN            NaN  0.867020  0.867020      1.16   NaN
#
#            NDVI_interp
# Date
# 2003-01-01         NaN
# 2003-01-02         NaN
# 2003-01-03         NaN
# 2003-01-04         NaN
# 2003-01-05         NaN
#
# [5 rows x 55 columns]
# Station 173:
#                  Date    NDVI  NDVI_interp
# 2003-01-03 2003-01-03  0.7637     0.782531
# 2003-01-04        NaT     NaN     0.780445
# 2003-01-05        NaT     NaN     0.778615
# 2003-01-06        NaT     NaN     0.777018
# 2003-01-07        NaT     NaN     0.775634
# 2003-01-08        NaT     NaN     0.774448
# 2003-01-09        NaT     NaN     0.773442
# 2003-01-10        NaT     NaN     0.772603
# 2003-01-11 2003-01-11  0.8150     0.771919
# 2003-01-12        NaT     NaN     0.771379
# 2003-01-13        NaT     NaN     0.770971
# 2003-01-14        NaT     NaN     0.770687
# 2003-01-15        NaT     NaN     0.770518
# 2003-01-16        NaT     NaN     0.770458
# 2003-01-17        NaT     NaN     0.770497
# 2003-01-18        NaT     NaN     0.770631
# 2003-01-19 2003-01-19  0.7663     0.770853
# 2003-01-20        NaT     NaN     0.771158
# 2003-01-21        NaT     NaN     0.771638
# 2003-01-22        NaT     NaN     0.772281
# 2003-01-23        NaT     NaN     0.773079
# 2003-01-24        NaT     NaN     0.774023
# 2003-01-25        NaT     NaN     0.775104
# 2003-01-26        NaT     NaN     0.776316
# 2003-01-27 2003-01-27  0.8070     0.777651
# 2003-01-28        NaT     NaN     0.779103
# 2003-01-29        NaT     NaN     0.780480
# 2003-01-30        NaT     NaN     0.781786
# 2003-01-31        NaT     NaN     0.783026
# 2003-02-01        NaT     NaN     0.784202
# 2003-02-02        NaT     NaN     0.785316
# 2003-02-03        NaT     NaN     0.786373
# 2003-02-04 2003-02-04  0.7137     0.787375
# 2003-02-05        NaT     NaN     0.788709
# 2003-02-06        NaT     NaN     0.789921
#                  Date  Doy  Station Standard  \
# Date
# 2003-01-01 2003-01-01    1      173   metric
# 2003-01-02 2003-01-02    2      173   metric
# 2003-01-03 2003-01-03    3      173   metric
# 2003-01-04 2003-01-04    4      173   metric
# 2003-01-05 2003-01-05    5      173   metric
#
#                                      ZipCodes  Scope  Tavg Tavg_Qc  Tmax  \
# Date
# 2003-01-01  92093, 92092, 92039, 92038, 92037  daily  12.0          15.8
# 2003-01-02  92093, 92092, 92039, 92038, 92037  daily  15.5          20.7
# 2003-01-03  92093, 92092, 92039, 92038, 92037  daily  18.2          23.6
# 2003-01-04  92093, 92092, 92039, 92038, 92037  daily  17.1          23.7
# 2003-01-05  92093, 92092, 92039, 92038, 92037  daily  17.0          22.4
#
#            Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg Tmin_diff_avg  \
# Date                ...
# 2003-01-01          ...       0.00      0.00            NaN           NaN
# 2003-01-02          ...       2.70     -6.30            NaN           NaN
# 2003-01-03          ...       0.00      0.00            NaN           NaN
# 2003-01-04          ...       2.55     -5.95            NaN           NaN
# 2003-01-05          ...       2.40     -5.60            NaN           NaN
#
#             Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI NDVI_interp
# Date
# 2003-01-01            NaN  1.483188  1.483188      1.69     NaN         NaN
# 2003-01-02            NaN  1.463446  1.291621       NaN     NaN         NaN
# 2003-01-03            NaN  1.834521  1.834521      2.56  0.7637    0.782531
# 2003-01-04            NaN  2.158912  1.671375       NaN     NaN    0.780445
# 2003-01-05            NaN  1.779370  1.503792       NaN     NaN    0.778615
#
# [5 rows x 55 columns]
# Station 174:
#                  Date    NDVI  NDVI_interp
# 2003-01-02 2003-01-02  0.8033     0.784044
# 2003-01-03        NaT     NaN     0.784688
# 2003-01-04        NaT     NaN     0.785262
# 2003-01-05        NaT     NaN     0.785773
# 2003-01-06        NaT     NaN     0.786225
# 2003-01-07        NaT     NaN     0.786624
# 2003-01-08        NaT     NaN     0.786973
# 2003-01-09        NaT     NaN     0.787277
# 2003-01-10        NaT     NaN     0.787538
# 2003-01-11        NaT     NaN     0.787760
# 2003-01-12        NaT     NaN     0.787946
# 2003-01-13        NaT     NaN     0.788098
# 2003-01-14        NaT     NaN     0.788219
# 2003-01-15        NaT     NaN     0.788310
# 2003-01-16        NaT     NaN     0.788374
# 2003-01-17        NaT     NaN     0.788412
# 2003-01-18 2003-01-18  0.8045     0.788426
# 2003-01-19        NaT     NaN     0.788417
# 2003-01-20        NaT     NaN     0.788387
# 2003-01-21        NaT     NaN     0.788337
# 2003-01-22        NaT     NaN     0.788269
# 2003-01-23        NaT     NaN     0.788182
# 2003-01-24        NaT     NaN     0.788078
# 2003-01-25        NaT     NaN     0.787959
# 2003-01-26 2003-01-26  0.7236     0.787825
# 2003-01-27        NaT     NaN     0.787676
# 2003-01-28        NaT     NaN     0.787514
# 2003-01-29        NaT     NaN     0.787339
# 2003-01-30        NaT     NaN     0.787151
# 2003-01-31        NaT     NaN     0.786953
# 2003-02-01        NaT     NaN     0.786743
# 2003-02-02        NaT     NaN     0.786523
# 2003-02-03 2003-02-03  0.8053     0.786292
# 2003-02-04        NaT     NaN     0.785783
# 2003-02-05        NaT     NaN     0.785257
#                  Date  Doy  Station Standard  \
# Date
# 2003-01-01 2003-01-01    1      174   metric
# 2003-01-02 2003-01-02    2      174   metric
# 2003-01-03 2003-01-03    3      174   metric
# 2003-01-04 2003-01-04    4      174   metric
# 2003-01-05 2003-01-05    5      174   metric
#
#                                                      ZipCodes  Scope  Tavg  \
# Date
# 2003-01-01  90899, 90888, 90853, 90848, 90847, 90846, 9084...  daily  11.1
# 2003-01-02  90899, 90888, 90853, 90848, 90847, 90846, 9084...  daily  14.4
# 2003-01-03  90899, 90888, 90853, 90848, 90847, 90846, 9084...  daily  13.7
# 2003-01-04  90899, 90888, 90853, 90848, 90847, 90846, 9084...  daily  13.1
# 2003-01-05  90899, 90888, 90853, 90848, 90847, 90846, 9084...  daily  13.4
#
#            Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                              ...
# 2003-01-01          22.8          ...       0.00      0.00            NaN
# 2003-01-02          25.9          ...       0.54     -1.26            NaN
# 2003-01-03           NaN       Y  ...       0.00      0.00            NaN
# 2003-01-04          25.4          ...       0.00      0.00            NaN
# 2003-01-05          27.0          ...       0.00      0.00            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI  \
# Date
# 2003-01-01           NaN            NaN  1.398180  1.398180       NaN     NaN
# 2003-01-02           NaN            NaN  1.532266  1.490556       NaN  0.8033
# 2003-01-03           NaN            NaN       NaN       NaN      1.53     NaN
# 2003-01-04           NaN            NaN  1.546473  1.546473       NaN     NaN
# 2003-01-05           NaN            NaN  1.708517  1.708517       NaN     NaN
#
#            NDVI_interp
# Date
# 2003-01-01         NaN
# 2003-01-02    0.784044
# 2003-01-03    0.784688
# 2003-01-04    0.785262
# 2003-01-05    0.785773
#
# [5 rows x 55 columns]
# Station 175:
#                  Date    NDVI  NDVI_interp
# 2003-01-04 2003-01-04  0.5512     0.689647
# 2003-01-05 2003-01-05  0.5460     0.693682
# 2003-01-06        NaT     NaN     0.697229
# 2003-01-07        NaT     NaN     0.700728
# 2003-01-08        NaT     NaN     0.704181
# 2003-01-09        NaT     NaN     0.707592
# 2003-01-10        NaT     NaN     0.710965
# 2003-01-11        NaT     NaN     0.714303
# 2003-01-12 2003-01-12  0.5895     0.717607
# 2003-01-13 2003-01-13  0.6079     0.720882
# 2003-01-14        NaT     NaN     0.724129
# 2003-01-15        NaT     NaN     0.727349
# 2003-01-16        NaT     NaN     0.730545
# 2003-01-17        NaT     NaN     0.733718
# 2003-01-18        NaT     NaN     0.736870
# 2003-01-19        NaT     NaN     0.740001
# 2003-01-20        NaT     NaN     0.743115
# 2003-01-21 2003-01-21  0.6921     0.746210
# 2003-01-22        NaT     NaN     0.748186
# 2003-01-23        NaT     NaN     0.750061
# 2003-01-24        NaT     NaN     0.751842
# 2003-01-25        NaT     NaN     0.753533
# 2003-01-26        NaT     NaN     0.755140
# 2003-01-27        NaT     NaN     0.756668
# 2003-01-28        NaT     NaN     0.758120
# 2003-01-29 2003-01-29  0.8313     0.759500
# 2003-01-30        NaT     NaN     0.762055
# 2003-01-31        NaT     NaN     0.764474
# 2003-02-01        NaT     NaN     0.766762
# 2003-02-02        NaT     NaN     0.768927
# 2003-02-03        NaT     NaN     0.770975
# 2003-02-04        NaT     NaN     0.772910
# 2003-02-05 2003-02-05  0.8228     0.774739
# 2003-02-06 2003-02-06  0.8143     0.779986
# 2003-02-07        NaT     NaN     0.785282
#                  Date  Doy  Station Standard  ZipCodes  Scope  Tavg Tavg_Qc  \
# Date
# 2003-01-01 2003-01-01    1      175   metric     92266  daily   9.4
# 2003-01-02 2003-01-02    2      175   metric     92266  daily   9.7
# 2003-01-03 2003-01-03    3      175   metric     92266  daily  10.1
# 2003-01-04 2003-01-04    4      175   metric     92266  daily  11.4
# 2003-01-05 2003-01-05    5      175   metric     92266  daily  11.8
#
#             Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                      ...
# 2003-01-01  19.9          ...        0.0       0.0            NaN
# 2003-01-02  20.0          ...        0.0       0.0            NaN
# 2003-01-03  24.0          ...        0.0       0.0            NaN
# 2003-01-04  23.3          ...        0.0       0.0            NaN
# 2003-01-05  22.7          ...        0.0       0.0            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI  \
# Date
# 2003-01-01           NaN            NaN  2.141650  2.141650      2.11     NaN
# 2003-01-02           NaN            NaN  2.041002  2.041002      2.04     NaN
# 2003-01-03           NaN            NaN  2.234673  2.234673      1.77     NaN
# 2003-01-04           NaN            NaN  2.024534  2.024534      1.99  0.5512
# 2003-01-05           NaN            NaN  2.478932  2.478932      2.03  0.5460
#
#            NDVI_interp
# Date
# 2003-01-01         NaN
# 2003-01-02         NaN
# 2003-01-03         NaN
# 2003-01-04    0.689647
# 2003-01-05    0.693682
#
# [5 rows x 55 columns]
# Station 178:
#                  Date    NDVI  NDVI_interp
# 2003-01-07 2003-01-07  0.8588     0.868411
# 2003-01-08        NaT     NaN     0.868559
# 2003-01-09        NaT     NaN     0.868689
# 2003-01-10        NaT     NaN     0.868802
# 2003-01-11        NaT     NaN     0.868899
# 2003-01-12        NaT     NaN     0.868983
# 2003-01-13        NaT     NaN     0.869053
# 2003-01-14        NaT     NaN     0.869111
# 2003-01-15 2003-01-15  0.8676     0.869158
# 2003-01-16        NaT     NaN     0.869195
# 2003-01-17        NaT     NaN     0.869222
# 2003-01-18        NaT     NaN     0.869241
# 2003-01-19        NaT     NaN     0.869251
# 2003-01-20        NaT     NaN     0.869253
# 2003-01-21        NaT     NaN     0.869248
# 2003-01-22        NaT     NaN     0.869236
# 2003-01-23        NaT     NaN     0.869218
# 2003-01-24        NaT     NaN     0.869194
# 2003-01-25        NaT     NaN     0.869164
# 2003-01-26        NaT     NaN     0.869129
# 2003-01-27        NaT     NaN     0.869089
# 2003-01-28        NaT     NaN     0.869044
# 2003-01-29        NaT     NaN     0.868995
# 2003-01-30        NaT     NaN     0.868941
# 2003-01-31        NaT     NaN     0.868884
# 2003-02-01        NaT     NaN     0.868823
# 2003-02-02        NaT     NaN     0.868758
# 2003-02-03        NaT     NaN     0.868690
# 2003-02-04        NaT     NaN     0.868619
# 2003-02-05        NaT     NaN     0.868544
# 2003-02-06        NaT     NaN     0.868467
# 2003-02-07        NaT     NaN     0.868387
# 2003-02-08 2003-02-08  0.8733     0.868304
# 2003-02-09        NaT     NaN     0.868366
# 2003-02-10        NaT     NaN     0.868406
#                  Date  Doy  Station Standard  ZipCodes  Scope  Tavg Tavg_Qc  \
# Date
# 2003-01-01 2003-01-01    1      178   metric     94595  daily   6.6
# 2003-01-02 2003-01-02    2      178   metric     94595  daily   7.3
# 2003-01-03 2003-01-03    3      178   metric     94595  daily   8.0
# 2003-01-04 2003-01-04    4      178   metric     94595  daily  10.0
# 2003-01-05 2003-01-05    5      178   metric     94595  daily  10.7
#
#             Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                      ...
# 2003-01-01  12.6          ...        0.0       0.0            NaN
# 2003-01-02  11.3          ...        0.0       0.0            NaN
# 2003-01-03  14.3          ...        0.0       0.0            NaN
# 2003-01-04  18.7          ...        0.0       0.0            NaN
# 2003-01-05  18.7          ...        0.0       0.0            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS  NDVI  \
# Date
# 2003-01-01           NaN            NaN  0.701930  0.701930      1.02   NaN
# 2003-01-02           NaN            NaN  0.594971  0.594971      0.67   NaN
# 2003-01-03           NaN            NaN  0.920260  0.920260      1.31   NaN
# 2003-01-04           NaN            NaN  0.991930  0.991930      1.26   NaN
# 2003-01-05           NaN            NaN  1.262428  1.262428      1.56   NaN
#
#            NDVI_interp
# Date
# 2003-01-01         NaN
# 2003-01-02         NaN
# 2003-01-03         NaN
# 2003-01-04         NaN
# 2003-01-05         NaN
#
# [5 rows x 55 columns]
# Station 179:
#                  Date    NDVI  NDVI_interp
# 2003-01-11 2003-01-11  0.6184     0.247036
# 2003-01-12        NaT     NaN     0.245654
# 2003-01-13        NaT     NaN     0.244398
# 2003-01-14        NaT     NaN     0.243256
# 2003-01-15        NaT     NaN     0.242220
# 2003-01-16        NaT     NaN     0.241281
# 2003-01-17        NaT     NaN     0.240431
# 2003-01-18        NaT     NaN     0.239663
# 2003-01-19 2003-01-19  0.1855     0.238971
# 2003-01-20        NaT     NaN     0.238350
# 2003-01-21        NaT     NaN     0.237814
# 2003-01-22        NaT     NaN     0.237358
# 2003-01-23        NaT     NaN     0.236976
# 2003-01-24        NaT     NaN     0.236663
# 2003-01-25        NaT     NaN     0.236415
# 2003-01-26        NaT     NaN     0.236228
# 2003-01-27 2003-01-27  0.1773     0.236097
# 2003-01-28        NaT     NaN     0.236019
# 2003-01-29        NaT     NaN     0.235941
# 2003-01-30        NaT     NaN     0.235861
# 2003-01-31        NaT     NaN     0.235781
# 2003-02-01        NaT     NaN     0.235699
# 2003-02-02        NaT     NaN     0.235617
# 2003-02-03        NaT     NaN     0.235534
# 2003-02-04        NaT     NaN     0.235450
# 2003-02-05        NaT     NaN     0.235365
# 2003-02-06        NaT     NaN     0.235280
# 2003-02-07        NaT     NaN     0.235194
# 2003-02-08        NaT     NaN     0.235107
# 2003-02-09        NaT     NaN     0.235020
# 2003-02-10        NaT     NaN     0.234932
# 2003-02-11        NaT     NaN     0.234844
# 2003-02-12        NaT     NaN     0.234755
# 2003-02-13        NaT     NaN     0.228670
# 2003-02-14        NaT     NaN     0.223427
#                  Date  Doy  Station Standard             ZipCodes  Scope  \
# Date
# 2003-01-01 2003-01-01    1      179   metric  92596, 92584, 92548  daily
# 2003-01-02 2003-01-02    2      179   metric  92596, 92584, 92548  daily
# 2003-01-03 2003-01-03    3      179   metric  92596, 92584, 92548  daily
# 2003-01-04 2003-01-04    4      179   metric  92596, 92584, 92548  daily
# 2003-01-05 2003-01-05    5      179   metric  92596, 92584, 92548  daily
#
#             Tavg Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  \
# Date                                    ...
# 2003-01-01   8.9          21.3          ...        0.0       0.0
# 2003-01-02  10.7          23.9          ...        0.0       0.0
# 2003-01-03  12.2          25.4          ...        0.0       0.0
# 2003-01-04  13.3           NaN       Y  ...        0.0       0.0
# 2003-01-05  14.5           NaN       Y  ...        0.0       0.0
#
#             Tmax_diff_avg Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr  \
# Date
# 2003-01-01            NaN           NaN            NaN  1.989134  1.989134
# 2003-01-02            NaN           NaN            NaN  2.395248  2.395248
# 2003-01-03            NaN           NaN            NaN  2.315927  2.315927
# 2003-01-04            NaN           NaN            NaN       NaN       NaN
# 2003-01-05            NaN           NaN            NaN       NaN       NaN
#
#            ETo_CIMIS  NDVI NDVI_interp
# Date
# 2003-01-01      1.82   NaN         NaN
# 2003-01-02      2.18   NaN         NaN
# 2003-01-03      1.94   NaN         NaN
# 2003-01-04      1.92   NaN         NaN
# 2003-01-05      2.37   NaN         NaN
#
# [5 rows x 55 columns]
# Station 181:
#                  Date    NDVI  NDVI_interp
# 2003-01-04 2003-01-04  0.7734     0.672420
# 2003-01-05        NaT     NaN     0.673138
# 2003-01-06        NaT     NaN     0.674178
# 2003-01-07        NaT     NaN     0.675512
# 2003-01-08        NaT     NaN     0.677117
# 2003-01-09        NaT     NaN     0.678970
# 2003-01-10        NaT     NaN     0.681051
# 2003-01-11        NaT     NaN     0.683344
# 2003-01-12 2003-01-12  0.8468     0.685832
# 2003-01-13        NaT     NaN     0.688501
# 2003-01-14        NaT     NaN     0.691337
# 2003-01-15        NaT     NaN     0.694330
# 2003-01-16        NaT     NaN     0.697469
# 2003-01-17        NaT     NaN     0.700744
# 2003-01-18        NaT     NaN     0.704145
# 2003-01-19        NaT     NaN     0.707666
# 2003-01-20 2003-01-20  0.7783     0.711298
# 2003-01-21        NaT     NaN     0.715035
# 2003-01-22        NaT     NaN     0.718518
# 2003-01-23        NaT     NaN     0.721763
# 2003-01-24        NaT     NaN     0.724784
# 2003-01-25        NaT     NaN     0.727593
# 2003-01-26        NaT     NaN     0.730202
# 2003-01-27        NaT     NaN     0.732621
# 2003-01-28 2003-01-28  0.3250     0.734862
# 2003-01-29        NaT     NaN     0.736932
# 2003-01-30        NaT     NaN     0.739004
# 2003-01-31        NaT     NaN     0.741076
# 2003-02-01        NaT     NaN     0.743150
# 2003-02-02        NaT     NaN     0.745223
# 2003-02-03        NaT     NaN     0.747298
# 2003-02-04        NaT     NaN     0.749373
# 2003-02-05 2003-02-05  0.6961     0.751448
# 2003-02-06        NaT     NaN     0.753214
# 2003-02-07        NaT     NaN     0.754625
#                  Date  Doy  Station Standard                    ZipCodes  \
# Date
# 2004-03-24 2004-03-24   84      181   metric  92227, 92233, 92251, 92281
# 2004-03-25 2004-03-25   85      181   metric  92227, 92233, 92251, 92281
# 2004-03-26 2004-03-26   86      181   metric  92227, 92233, 92251, 92281
# 2004-03-27 2004-03-27   87      181   metric  92227, 92233, 92251, 92281
# 2004-03-28 2004-03-28   88      181   metric  92227, 92233, 92251, 92281
#
#             Scope  Tavg Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  \
# Date                                           ...
# 2004-03-24  daily  23.2       H  30.1          ...        NaN       0.0
# 2004-03-25  daily  21.5       H  30.9          ...        0.0       0.0
# 2004-03-26  daily  21.8          27.6          ...        NaN       0.0
# 2004-03-27  daily  19.5          29.7          ...        0.0       0.0
# 2004-03-28  daily  19.3          30.9          ...        0.0       0.0
#
#             Tmax_diff_avg Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr  \
# Date
# 2004-03-24            NaN           NaN            NaN       NaN       NaN
# 2004-03-25            NaN           NaN            NaN       NaN       NaN
# 2004-03-26            NaN           NaN            NaN       NaN       NaN
# 2004-03-27            NaN           NaN            NaN  5.032403  5.032403
# 2004-03-28            NaN           NaN            NaN  5.974523  5.974523
#
#            ETo_CIMIS    NDVI NDVI_interp
# Date
# 2004-03-24       NaN     NaN    0.588009
# 2004-03-25       NaN     NaN    0.591088
# 2004-03-26      8.10     NaN    0.593814
# 2004-03-27      5.04  0.4526    0.596185
# 2004-03-28      6.04     NaN    0.598202
#
# [5 rows x 55 columns]
# Station 182:
#                  Date    NDVI  NDVI_interp
# 2003-01-01 2003-01-01  0.3306     0.369737
# 2003-01-02        NaT     NaN     0.371000
# 2003-01-03        NaT     NaN     0.372160
# 2003-01-04        NaT     NaN     0.373225
# 2003-01-05        NaT     NaN     0.374204
# 2003-01-06        NaT     NaN     0.375104
# 2003-01-07        NaT     NaN     0.375931
# 2003-01-08        NaT     NaN     0.376690
# 2003-01-09        NaT     NaN     0.377387
# 2003-01-10        NaT     NaN     0.378027
# 2003-01-11        NaT     NaN     0.378612
# 2003-01-12        NaT     NaN     0.379148
# 2003-01-13        NaT     NaN     0.379637
# 2003-01-14        NaT     NaN     0.380083
# 2003-01-15        NaT     NaN     0.380489
# 2003-01-16        NaT     NaN     0.380856
# 2003-01-17        NaT     NaN     0.381188
# 2003-01-18        NaT     NaN     0.381486
# 2003-01-19        NaT     NaN     0.381811
# 2003-01-20        NaT     NaN     0.382161
# 2003-01-21        NaT     NaN     0.382536
# 2003-01-22        NaT     NaN     0.382933
# 2003-01-23        NaT     NaN     0.383351
# 2003-01-24        NaT     NaN     0.383789
# 2003-01-25        NaT     NaN     0.384247
# 2003-01-26        NaT     NaN     0.384722
# 2003-01-27        NaT     NaN     0.385215
# 2003-01-28        NaT     NaN     0.385724
# 2003-01-29        NaT     NaN     0.386248
# 2003-01-30        NaT     NaN     0.386787
# 2003-01-31        NaT     NaN     0.387340
# 2003-02-01        NaT     NaN     0.387906
# 2003-02-02 2003-02-02  0.4114     0.388485
# 2003-02-03        NaT     NaN     0.389990
# 2003-02-04        NaT     NaN     0.391528
#                  Date  Doy  Station Standard  \
# Date
# 2003-01-01 2003-01-01    1      182   metric
# 2003-01-02 2003-01-02    2      182   metric
# 2003-01-03 2003-01-03    3      182   metric
# 2003-01-04 2003-01-04    4      182   metric
# 2003-01-05 2003-01-05    5      182   metric
#
#                                             ZipCodes  Scope  Tavg Tavg_Qc  \
# Date
# 2003-01-01  93261, 93250, 93219, 93216, 93215, 93201  daily   6.4
# 2003-01-02  93261, 93250, 93219, 93216, 93215, 93201  daily   7.5
# 2003-01-03  93261, 93250, 93219, 93216, 93215, 93201  daily   6.6
# 2003-01-04  93261, 93250, 93219, 93216, 93215, 93201  daily   6.7
# 2003-01-05  93261, 93250, 93219, 93216, 93215, 93201  daily   7.3
#
#             Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                      ...
# 2003-01-01  13.7          ...        0.0       0.0            NaN
# 2003-01-02  15.6          ...        0.0       0.0            NaN
# 2003-01-03  12.2          ...        0.0       0.0            NaN
# 2003-01-04  12.7          ...        0.0       0.0            NaN
# 2003-01-05   9.0          ...        0.0       0.0            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI  \
# Date
# 2003-01-01           NaN            NaN  0.919075  0.919075      1.16  0.3306
# 2003-01-02           NaN            NaN  0.937518  0.937518      1.28     NaN
# 2003-01-03           NaN            NaN  0.720414  0.720414      0.59     NaN
# 2003-01-04           NaN            NaN  0.677104  0.677104      0.63     NaN
# 2003-01-05           NaN            NaN  0.239790  0.239790      0.04     NaN
#
#            NDVI_interp
# Date
# 2003-01-01    0.369737
# 2003-01-02    0.371000
# 2003-01-03    0.372160
# 2003-01-04    0.373225
# 2003-01-05    0.374204
#
# [5 rows x 55 columns]
# Station 184:
#                  Date    NDVI  NDVI_interp
# 2003-01-03 2003-01-03  0.7881     0.804445
# 2003-01-04        NaT     NaN     0.803741
# 2003-01-05        NaT     NaN     0.803186
# 2003-01-06        NaT     NaN     0.802767
# 2003-01-07        NaT     NaN     0.802474
# 2003-01-08        NaT     NaN     0.802296
# 2003-01-09        NaT     NaN     0.802223
# 2003-01-10        NaT     NaN     0.802249
# 2003-01-11 2003-01-11  0.8301     0.802364
# 2003-01-12        NaT     NaN     0.802564
# 2003-01-13        NaT     NaN     0.802842
# 2003-01-14        NaT     NaN     0.803191
# 2003-01-15        NaT     NaN     0.803609
# 2003-01-16        NaT     NaN     0.804089
# 2003-01-17        NaT     NaN     0.804628
# 2003-01-18        NaT     NaN     0.805223
# 2003-01-19 2003-01-19  0.7955     0.805869
# 2003-01-20        NaT     NaN     0.806563
# 2003-01-21        NaT     NaN     0.807244
# 2003-01-22        NaT     NaN     0.807911
# 2003-01-23        NaT     NaN     0.808565
# 2003-01-24        NaT     NaN     0.809208
# 2003-01-25        NaT     NaN     0.809840
# 2003-01-26        NaT     NaN     0.810461
# 2003-01-27 2003-01-27  0.8071     0.811072
# 2003-01-28        NaT     NaN     0.811673
# 2003-01-29        NaT     NaN     0.812266
# 2003-01-30        NaT     NaN     0.812850
# 2003-01-31        NaT     NaN     0.813426
# 2003-02-01        NaT     NaN     0.813994
# 2003-02-02        NaT     NaN     0.814555
# 2003-02-03        NaT     NaN     0.815109
# 2003-02-04 2003-02-04  0.7812     0.815656
# 2003-02-05        NaT     NaN     0.816636
# 2003-02-06        NaT     NaN     0.817545
#                  Date  Doy  Station Standard  \
# Date
# 2003-01-01 2003-01-01    1      184   metric
# 2003-01-02 2003-01-02    2      184   metric
# 2003-01-03 2003-01-03    3      184   metric
# 2003-01-04 2003-01-04    4      184   metric
# 2003-01-05 2003-01-05    5      184   metric
#
#                                                      ZipCodes  Scope  Tavg  \
# Date
# 2003-01-01  92199, 92198, 92197, 92196, 92195, 92194, 9219...  daily  12.5
# 2003-01-02  92199, 92198, 92197, 92196, 92195, 92194, 9219...  daily  15.1
# 2003-01-03  92199, 92198, 92197, 92196, 92195, 92194, 9219...  daily  20.6
# 2003-01-04  92199, 92198, 92197, 92196, 92195, 92194, 9219...  daily  17.3
# 2003-01-05  92199, 92198, 92197, 92196, 92195, 92194, 9219...  daily  16.7
#
#            Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                              ...
# 2003-01-01          20.3          ...       0.00      0.00            NaN
# 2003-01-02          24.4          ...       1.44     -3.36            NaN
# 2003-01-03           NaN       Y  ...        NaN      0.00            NaN
# 2003-01-04          25.6          ...       1.92     -4.48            NaN
# 2003-01-05          24.0          ...       1.38     -3.22            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI  \
# Date
# 2003-01-01           NaN            NaN  1.771072  1.771072      1.95     NaN
# 2003-01-02           NaN            NaN  2.691004  2.317484      2.61     NaN
# 2003-01-03           NaN            NaN       NaN       NaN      2.83  0.7881
# 2003-01-04           NaN            NaN  2.579190  2.106086      2.58     NaN
# 2003-01-05           NaN            NaN  2.380823  2.025724      2.46     NaN
#
#            NDVI_interp
# Date
# 2003-01-01         NaN
# 2003-01-02         NaN
# 2003-01-03    0.804445
# 2003-01-04    0.803741
# 2003-01-05    0.803186
#
# [5 rows x 55 columns]
# Station 187:
#                  Date    NDVI  NDVI_interp
# 2003-01-06 2003-01-06  0.7313     0.789991
# 2003-01-07        NaT     NaN     0.790755
# 2003-01-08        NaT     NaN     0.793335
# 2003-01-09        NaT     NaN     0.795558
# 2003-01-10        NaT     NaN     0.797451
# 2003-01-11        NaT     NaN     0.799043
# 2003-01-12        NaT     NaN     0.800356
# 2003-01-13        NaT     NaN     0.801413
# 2003-01-14        NaT     NaN     0.802232
# 2003-01-15 2003-01-15  0.7910     0.802830
# 2003-01-16        NaT     NaN     0.803225
# 2003-01-17        NaT     NaN     0.803055
# 2003-01-18        NaT     NaN     0.802359
# 2003-01-19        NaT     NaN     0.801172
# 2003-01-20        NaT     NaN     0.799526
# 2003-01-21        NaT     NaN     0.797450
# 2003-01-22        NaT     NaN     0.794972
# 2003-01-23        NaT     NaN     0.792115
# 2003-01-24        NaT     NaN     0.789754
# 2003-01-25        NaT     NaN     0.787860
# 2003-01-26        NaT     NaN     0.786405
# 2003-01-27        NaT     NaN     0.785364
# 2003-01-28        NaT     NaN     0.784716
# 2003-01-29        NaT     NaN     0.784437
# 2003-01-30        NaT     NaN     0.784509
# 2003-01-31        NaT     NaN     0.784913
# 2003-02-01        NaT     NaN     0.785632
# 2003-02-02        NaT     NaN     0.786366
# 2003-02-03        NaT     NaN     0.787115
# 2003-02-04        NaT     NaN     0.787879
# 2003-02-05        NaT     NaN     0.788655
# 2003-02-06        NaT     NaN     0.789445
# 2003-02-07 2003-02-07  0.8152     0.790246
# 2003-02-08 2003-02-08  0.8785     0.791993
# 2003-02-09        NaT     NaN     0.793528
#                  Date  Doy  Station Standard      ZipCodes  Scope  Tavg  \
# Date
# 2003-06-15 2003-06-15  166      187   metric  94945, 94949  daily  16.9
# 2003-06-16 2003-06-16  167      187   metric  94945, 94949  daily  18.0
# 2003-06-17 2003-06-17  168      187   metric  94945, 94949  daily  16.5
# 2003-06-18 2003-06-18  169      187   metric  94945, 94949  daily  15.9
# 2003-06-19 2003-06-19  170      187   metric  94945, 94949  daily  15.4
#
#            Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                              ...
# 2003-06-15          28.5          ...        0.0       NaN            NaN
# 2003-06-16          30.0          ...        0.0       NaN            NaN
# 2003-06-17          24.0          ...        0.0       NaN            NaN
# 2003-06-18          23.2          ...        0.0       NaN            NaN
# 2003-06-19          22.5          ...        0.0       NaN            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI  \
# Date
# 2003-06-15           NaN            NaN       NaN       NaN       NaN  0.4509
# 2003-06-16           NaN            NaN       NaN       NaN       NaN     NaN
# 2003-06-17           NaN            NaN       NaN       NaN       NaN     NaN
# 2003-06-18           NaN            NaN       NaN       NaN       NaN     NaN
# 2003-06-19           NaN            NaN       NaN       NaN       NaN     NaN
#
#            NDVI_interp
# Date
# 2003-06-15    0.544163
# 2003-06-16    0.544592
# 2003-06-17    0.545322
# 2003-06-18    0.546028
# 2003-06-19    0.546708
#
# [5 rows x 55 columns]
# Station 191:
#                  Date    NDVI  NDVI_interp
# 2003-06-24 2003-06-24  0.7458     0.728105
# 2003-06-25        NaT     NaN     0.727080
# 2003-06-26        NaT     NaN     0.726323
# 2003-06-27        NaT     NaN     0.725809
# 2003-06-28        NaT     NaN     0.725519
# 2003-06-29        NaT     NaN     0.725435
# 2003-06-30        NaT     NaN     0.725540
# 2003-07-01        NaT     NaN     0.725820
# 2003-07-02        NaT     NaN     0.726261
# 2003-07-03        NaT     NaN     0.726852
# 2003-07-04        NaT     NaN     0.727405
# 2003-07-05        NaT     NaN     0.727922
# 2003-07-06        NaT     NaN     0.728405
# 2003-07-07        NaT     NaN     0.728857
# 2003-07-08        NaT     NaN     0.729280
# 2003-07-09        NaT     NaN     0.729676
# 2003-07-10 2003-07-10  0.7235     0.730046
# 2003-07-11        NaT     NaN     0.730392
# 2003-07-12        NaT     NaN     0.730789
# 2003-07-13        NaT     NaN     0.731234
# 2003-07-14        NaT     NaN     0.731725
# 2003-07-15        NaT     NaN     0.732258
# 2003-07-16        NaT     NaN     0.732832
# 2003-07-17        NaT     NaN     0.733445
# 2003-07-18 2003-07-18  0.7310     0.734093
# 2003-07-19        NaT     NaN     0.734775
# 2003-07-20        NaT     NaN     0.735396
# 2003-07-21        NaT     NaN     0.735957
# 2003-07-22        NaT     NaN     0.736462
# 2003-07-23        NaT     NaN     0.736913
# 2003-07-24        NaT     NaN     0.737314
# 2003-07-25        NaT     NaN     0.737666
# 2003-07-26 2003-07-26  0.6943     0.737972
# 2003-07-27        NaT     NaN     0.738116
# 2003-07-28        NaT     NaN     0.738292
#                  Date  Doy  Station Standard  ZipCodes  Scope  Tavg Tavg_Qc  \
# Date
# 2004-04-21 2004-04-21  112      191   metric     94588  daily  11.3       H
# 2004-04-22 2004-04-22  113      191   metric     94588  daily  14.9
# 2004-04-23 2004-04-23  114      191   metric     94588  daily  17.3
# 2004-04-24 2004-04-24  115      191   metric     94588  daily  19.4
# 2004-04-25 2004-04-25  116      191   metric     94588  daily  21.1
#
#             Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                      ...
# 2004-04-21  14.7          ...        NaN       0.0            NaN
# 2004-04-22  24.3          ...        0.0       0.0            NaN
# 2004-04-23  28.0          ...        0.0       0.0            NaN
# 2004-04-24  31.2          ...        0.0       0.0            NaN
# 2004-04-25   NaN       Y  ...        0.0       0.0            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI  \
# Date
# 2004-04-21           NaN            NaN       NaN       NaN       NaN     NaN
# 2004-04-22           NaN            NaN  4.935128  4.935128      5.69     NaN
# 2004-04-23           NaN            NaN  5.187507  5.187507      5.71  0.7919
# 2004-04-24           NaN            NaN  5.270203  5.270203      5.74     NaN
# 2004-04-25           NaN            NaN       NaN       NaN      6.00     NaN
#
#            NDVI_interp
# Date
# 2004-04-21    0.780244
# 2004-04-22    0.779279
# 2004-04-23    0.778398
# 2004-04-24    0.777602
# 2004-04-25    0.776901
#
# [5 rows x 55 columns]
# Station 192:
#                  Date    NDVI  NDVI_interp
# 2003-01-11 2003-01-11  0.6383     0.553061
# 2003-01-12        NaT     NaN     0.552308
# 2003-01-13        NaT     NaN     0.551731
# 2003-01-14        NaT     NaN     0.551314
# 2003-01-15        NaT     NaN     0.551044
# 2003-01-16        NaT     NaN     0.550909
# 2003-01-17        NaT     NaN     0.550898
# 2003-01-18        NaT     NaN     0.551002
# 2003-01-19 2003-01-19  0.6047     0.551212
# 2003-01-20        NaT     NaN     0.551520
# 2003-01-21        NaT     NaN     0.551920
# 2003-01-22        NaT     NaN     0.552405
# 2003-01-23        NaT     NaN     0.552969
# 2003-01-24        NaT     NaN     0.553607
# 2003-01-25        NaT     NaN     0.554314
# 2003-01-26        NaT     NaN     0.555085
# 2003-01-27 2003-01-27  0.5248     0.555917
# 2003-01-28        NaT     NaN     0.556807
# 2003-01-29        NaT     NaN     0.557749
# 2003-01-30        NaT     NaN     0.558742
# 2003-01-31        NaT     NaN     0.559783
# 2003-02-01        NaT     NaN     0.560868
# 2003-02-02        NaT     NaN     0.561995
# 2003-02-03        NaT     NaN     0.563163
# 2003-02-04 2003-02-04  0.4926     0.564368
# 2003-02-05        NaT     NaN     0.565609
# 2003-02-06        NaT     NaN     0.566885
# 2003-02-07        NaT     NaN     0.568192
# 2003-02-08        NaT     NaN     0.569530
# 2003-02-09        NaT     NaN     0.570897
# 2003-02-10        NaT     NaN     0.572292
# 2003-02-11        NaT     NaN     0.573713
# 2003-02-12        NaT     NaN     0.575160
# 2003-02-13        NaT     NaN     0.575667
# 2003-02-14        NaT     NaN     0.576309
#                  Date  Doy  Station Standard  ZipCodes  Scope  Tavg Tavg_Qc  \
# Date
# 2004-03-11 2004-03-11   71      192   metric     92352  daily   6.3       H
# 2004-03-12 2004-03-12   72      192   metric     92352  daily   8.5
# 2004-03-13 2004-03-13   73      192   metric     92352  daily   8.2
# 2004-03-14 2004-03-14   74      192   metric     92352  daily   8.8
# 2004-03-15 2004-03-15   75      192   metric     92352  daily   9.8
#
#             Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                      ...
# 2004-03-11  17.1          ...        0.0       0.0            NaN
# 2004-03-12  19.3          ...        0.0       0.0            NaN
# 2004-03-13  20.3          ...        0.0       0.0            NaN
# 2004-03-14  23.4          ...        0.0       0.0            NaN
# 2004-03-15  22.4          ...        0.0       0.0            NaN
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS  NDVI  \
# Date
# 2004-03-11           NaN            NaN       NaN       NaN       NaN   NaN
# 2004-03-12           NaN            NaN  3.786195  3.786195      4.05   NaN
# 2004-03-13           NaN            NaN       NaN       NaN      4.15   NaN
# 2004-03-14           NaN            NaN  4.132682  4.132682      4.18   NaN
# 2004-03-15           NaN            NaN  4.124840  4.124840      4.25   NaN
#
#            NDVI_interp
# Date
# 2004-03-11    0.473623
# 2004-03-12    0.477102
# 2004-03-13    0.480648
# 2004-03-14    0.484264
# 2004-03-15    0.487948
#
# [5 rows x 55 columns]
# Station 193:
#                  Date    NDVI  NDVI_interp
# 2003-01-11 2003-01-11  0.6383     0.553061
# 2003-01-12        NaT     NaN     0.552308
# 2003-01-13        NaT     NaN     0.551731
# 2003-01-14        NaT     NaN     0.551314
# 2003-01-15        NaT     NaN     0.551044
# 2003-01-16        NaT     NaN     0.550909
# 2003-01-17        NaT     NaN     0.550898
# 2003-01-18        NaT     NaN     0.551002
# 2003-01-19 2003-01-19  0.6047     0.551212
# 2003-01-20        NaT     NaN     0.551520
# 2003-01-21        NaT     NaN     0.551920
# 2003-01-22        NaT     NaN     0.552405
# 2003-01-23        NaT     NaN     0.552969
# 2003-01-24        NaT     NaN     0.553607
# 2003-01-25        NaT     NaN     0.554314
# 2003-01-26        NaT     NaN     0.555085
# 2003-01-27 2003-01-27  0.5248     0.555917
# 2003-01-28        NaT     NaN     0.556807
# 2003-01-29        NaT     NaN     0.557749
# 2003-01-30        NaT     NaN     0.558742
# 2003-01-31        NaT     NaN     0.559783
# 2003-02-01        NaT     NaN     0.560868
# 2003-02-02        NaT     NaN     0.561995
# 2003-02-03        NaT     NaN     0.563163
# 2003-02-04 2003-02-04  0.4926     0.564368
# 2003-02-05        NaT     NaN     0.565609
# 2003-02-06        NaT     NaN     0.566885
# 2003-02-07        NaT     NaN     0.568192
# 2003-02-08        NaT     NaN     0.569530
# 2003-02-09        NaT     NaN     0.570897
# 2003-02-10        NaT     NaN     0.572292
# 2003-02-11        NaT     NaN     0.573713
# 2003-02-12        NaT     NaN     0.575160
# 2003-02-13        NaT     NaN     0.575667
# 2003-02-14        NaT     NaN     0.576309
#                  Date  Doy  Station Standard  \
# Date
# 2011-10-26 2011-10-26  299      193   metric
# 2011-10-27 2011-10-27  300      193   metric
# 2011-10-28 2011-10-28  301      193   metric
# 2011-10-29 2011-10-29  302      193   metric
# 2011-10-30 2011-10-30  303      193   metric
#
#                                      ZipCodes  Scope  Tavg Tavg_Qc  Tmax  \
# Date
# 2011-10-26  93950, 93953, 93942, 93943, 93955  daily  12.6       H  16.4
# 2011-10-27  93950, 93953, 93942, 93943, 93955  daily  12.9          18.0
# 2011-10-28  93950, 93953, 93942, 93943, 93955  daily  13.0          19.0
# 2011-10-29  93950, 93953, 93942, 93943, 93955  daily  13.0          17.9
# 2011-10-30  93950, 93953, 93942, 93943, 93955  daily  12.1          18.0
#
#            Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg Tmin_diff_avg  \
# Date                ...
# 2011-10-26          ...        0.0       0.0            NaN           NaN
# 2011-10-27          ...        0.0       0.0            NaN           NaN
# 2011-10-28          ...        0.0       0.0            NaN           NaN
# 2011-10-29          ...        0.0       0.0            NaN           NaN
# 2011-10-30          ...        0.0       0.0            NaN           NaN
#
#             Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS  NDVI NDVI_interp
# Date
# 2011-10-26            NaN       NaN       NaN       NaN   NaN    0.790704
# 2011-10-27            NaN       NaN       NaN      2.66   NaN    0.789341
# 2011-10-28            NaN       NaN       NaN      2.57   NaN    0.787946
# 2011-10-29            NaN       NaN       NaN      2.48   NaN    0.786519
# 2011-10-30            NaN  1.526663  1.526663      1.81   NaN    0.785060
#
# ...
# 2020-02-26 2020-02-26   57      262   metric
# 2020-02-27 2020-02-27   58      262   metric
# 2020-02-28 2020-02-28   59      262   metric
# 2020-02-29 2020-02-29   60      262   metric
#
#                                                    ZipCodes  Scope  Tavg  \
# Date
# 2019-12-31  95240, 95236, 95227, 95237, 95252, 95212, 95215  daily   8.5
# 2020-02-26  95240, 95236, 95227, 95237, 95252, 95212, 95215  daily  11.3
# 2020-02-27  95240, 95236, 95227, 95237, 95252, 95212, 95215  daily  12.3
# 2020-02-28  95240, 95236, 95227, 95237, 95252, 95212, 95215  daily  14.9
# 2020-02-29  95240, 95236, 95227, 95237, 95252, 95212, 95215  daily  12.2
#
#            Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg  \
# Date                              ...
# 2019-12-31       H  15.1          ...        0.0       0.0            0.0
# 2020-02-26       H  22.2          ...        0.0       0.0            NaN
# 2020-02-27          24.4          ...        0.0       0.0            NaN
# 2020-02-28           NaN       Y  ...        0.0       0.0            NaN
# 2020-02-29          19.5          ...        0.0       0.0            0.0
#
#            Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS  NDVI  \
# Date
# 2019-12-31           0.0            0.0       NaN       NaN       NaN   NaN
# 2020-02-26           NaN            NaN       NaN       NaN       NaN   NaN
# 2020-02-27           NaN            NaN  2.581134  2.581134      3.04   NaN
# 2020-02-28           NaN            NaN       NaN       NaN      2.89   NaN
# 2020-02-29           0.0            0.0  2.800803  2.800803      3.37   NaN
#
#            NDVI_interp
# Date
# 2019-12-31    0.595250
# 2020-02-26    0.686445
# 2020-02-27    0.688424
# 2020-02-28    0.690510
# 2020-02-29    0.692703
#
# [5 rows x 55 columns]
# Station 264:
#                  Date    NDVI  NDVI_interp
# 2003-02-09 2003-02-09  0.2594     0.286700
# 2003-02-10        NaT     NaN     0.287424
# 2003-02-11        NaT     NaN     0.288135
# 2003-02-12        NaT     NaN     0.288832
# 2003-02-13        NaT     NaN     0.289518
# 2003-02-14        NaT     NaN     0.290193
# 2003-02-15        NaT     NaN     0.290859
# 2003-02-16        NaT     NaN     0.291515
# 2003-02-17        NaT     NaN     0.292162
# 2003-02-18        NaT     NaN     0.292802
# 2003-02-19        NaT     NaN     0.293785
# 2003-02-20        NaT     NaN     0.295086
# 2003-02-21        NaT     NaN     0.296684
# 2003-02-22        NaT     NaN     0.298558
# 2003-02-23        NaT     NaN     0.300692
# 2003-02-24        NaT     NaN     0.303068
# 2003-02-25        NaT     NaN     0.305672
# 2003-02-26        NaT     NaN     0.308489
# 2003-02-27        NaT     NaN     0.311255
# 2003-02-28        NaT     NaN     0.313973
# 2003-03-01        NaT     NaN     0.316645
# 2003-03-02        NaT     NaN     0.319276
# 2003-03-03        NaT     NaN     0.321865
# 2003-03-04        NaT     NaN     0.324417
# 2003-03-05 2003-03-05  0.3028     0.326933
# 2003-03-06        NaT     NaN     0.329418
# 2003-03-07        NaT     NaN     0.331873
# 2003-03-08        NaT     NaN     0.334301
# 2003-03-09        NaT     NaN     0.336702
# 2003-03-10        NaT     NaN     0.339078
# 2003-03-11        NaT     NaN     0.341430
# 2003-03-12        NaT     NaN     0.343760
# 2003-03-13        NaT     NaN     0.346067
# 2003-03-14        NaT     NaN     0.349744
# 2003-03-15        NaT     NaN     0.353444
#                  Date  Doy  Station Standard  \
# Date
# 2019-12-31 2019-12-31  365      264   metric
# 2020-10-29 2020-10-29  303      264   metric
# 2020-10-30 2020-10-30  304      264   metric
# 2020-10-31 2020-10-31  305      264   metric
# 2020-11-01 2020-11-01  306      264   metric
#
#                                      ZipCodes  Scope  Tavg Tavg_Qc  Tmax  \
# Date
# 2019-12-31  96106, 96118, 96122, 96129, 96135  daily  -1.5       H   5.2
# 2020-10-29  96106, 96118, 96122, 96129, 96135  daily  12.1       H  22.4
# 2020-10-30  96106, 96118, 96122, 96129, 96135  daily   4.7          24.2
# 2020-10-31  96106, 96118, 96122, 96129, 96135  daily   6.5          23.5
# 2020-11-01  96106, 96118, 96122, 96129, 96135  daily   6.3          23.4
#
#            Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg Tmin_diff_avg  \
# Date                ...
# 2019-12-31          ...       0.00      0.00           0.00          0.00
# 2020-10-29          ...       1.56     -3.64            NaN           NaN
# 2020-10-30          ...       0.00      0.00            NaN           NaN
# 2020-10-31          ...       0.00      0.00           0.52          0.52
# 2020-11-01          ...       0.00      0.00            NaN           NaN
#
#             Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI NDVI_interp
# Date
# 2019-12-31       0.000000       NaN       NaN       NaN     NaN    0.339355
# 2020-10-29            NaN       NaN       NaN       NaN  0.2304    0.258698
# 2020-10-30            NaN  3.013232  3.013232       NaN     NaN    0.258733
# 2020-10-31      -1.213333  3.022856  3.022856       NaN     NaN    0.258669
# 2020-11-01            NaN  2.592489  2.592489       NaN     NaN    0.258506
#
# [5 rows x 55 columns]
# Station 265:
#                  Date    NDVI  NDVI_interp
# 2003-01-01 2003-01-01  0.3323     0.299328
# 2003-01-02        NaT     NaN     0.300560
# 2003-01-03        NaT     NaN     0.301813
# 2003-01-04        NaT     NaN     0.303084
# 2003-01-05        NaT     NaN     0.304374
# 2003-01-06        NaT     NaN     0.305679
# 2003-01-07        NaT     NaN     0.306999
# 2003-01-08 2003-01-08  0.2606     0.308333
# 2003-01-09        NaT     NaN     0.309680
# 2003-01-10        NaT     NaN     0.311036
# 2003-01-11        NaT     NaN     0.312399
# 2003-01-12        NaT     NaN     0.313771
# 2003-01-13        NaT     NaN     0.315150
# 2003-01-14        NaT     NaN     0.316535
# 2003-01-15        NaT     NaN     0.317927
# 2003-01-16        NaT     NaN     0.319324
# 2003-01-17        NaT     NaN     0.320727
# 2003-01-18        NaT     NaN     0.322135
# 2003-01-19        NaT     NaN     0.323548
# 2003-01-20        NaT     NaN     0.324966
# 2003-01-21        NaT     NaN     0.326387
# 2003-01-22        NaT     NaN     0.327813
# 2003-01-23        NaT     NaN     0.329243
# 2003-01-24        NaT     NaN     0.330676
# 2003-01-25        NaT     NaN     0.332113
# 2003-01-26        NaT     NaN     0.333553
# 2003-01-27        NaT     NaN     0.334996
# 2003-01-28        NaT     NaN     0.336442
# 2003-01-29        NaT     NaN     0.337891
# 2003-01-30        NaT     NaN     0.339342
# 2003-01-31        NaT     NaN     0.340796
# 2003-02-01        NaT     NaN     0.342252
# 2003-02-02        NaT     NaN     0.343711
# 2003-02-03        NaT     NaN     0.345310
# 2003-02-04        NaT     NaN     0.347053
#                  Date  Doy  Station Standard  \
# Date
# 2022-03-18 2022-03-18   77      265   metric
# 2022-03-19 2022-03-19   78      265   metric
# 2022-03-20 2022-03-20   79      265   metric
# 2022-03-21 2022-03-21   80      265   metric
# 2022-03-22 2022-03-22   81      265   metric
#
#                                      ZipCodes  Scope  Tavg Tavg_Qc  Tmax  \
# Date
# 2022-03-18  93426, 93446, 93447, 93451, 93465  daily  18.8       Y  25.0
# 2022-03-19  93426, 93446, 93447, 93451, 93465  daily  11.1          15.3
# 2022-03-20  93426, 93446, 93447, 93451, 93465  daily  12.3          19.8
# 2022-03-21  93426, 93446, 93447, 93451, 93465  daily  12.6          24.4
# 2022-03-22  93426, 93446, 93447, 93451, 93465  daily  16.1          28.9
#
#            Tmax_Qc  ...  Tmin_diff Tdew_diff  Tmax_diff_avg Tmin_diff_avg  \
# Date                ...
# 2022-03-18          ...        NaN       NaN            NaN           NaN
# 2022-03-19          ...       0.00      0.00            NaN           NaN
# 2022-03-20          ...       0.24     -0.56            NaN           NaN
# 2022-03-21          ...       0.00      0.00            NaN           NaN
# 2022-03-22          ...       0.00      0.00            NaN           NaN
#
#             Tdew_diff_avg ETo_uncor  ETo_corr ETo_CIMIS    NDVI NDVI_interp
# Date
# 2022-03-18            NaN       NaN       NaN       NaN  0.7031    0.691398
# 2022-03-19            NaN  2.210595  2.210595      1.87     NaN    0.695473
# 2022-03-20            NaN  4.428877  4.244456      4.62     NaN    0.699483
# 2022-03-21            NaN  4.092241  4.092241      4.29     NaN    0.703427
# 2022-03-22            NaN       NaN       NaN      4.45     NaN    0.707305
#
# [5 rows x 55 columns]
# Station 266:
#                  Date    NDVI  NDVI_interp
# 2003-01-01 2003-01-01  0.1683     0.184901
# 2003-01-02        NaT     NaN     0.184433
# 2003-01-03        NaT     NaN     0.183976
# 2003-01-04        NaT     NaN     0.183530
# 2003-01-05        NaT     NaN     0.183092
# 2003-01-06        NaT     NaN     0.182662
# 2003-01-07        NaT     NaN     0.182240
# 2003-01-08        NaT     NaN     0.181826
# 2003-01-09        NaT     NaN     0.181418
# 2003-01-10        NaT     NaN     0.180951
# 2003-01-11        NaT     NaN     0.180430
# 2003-01-12        NaT     NaN     0.179859
# 2003-01-13        NaT     NaN     0.179241
# 2003-01-14        NaT     NaN     0.178579
# 2003-01-15        NaT     NaN     0.177875
# 2003-01-16 2003-01-16  0.2101     0.177134
# 2003-01-17 2003-01-17  0.2010     0.176356
# 2003-01-18        NaT     NaN     0.175545
# 2003-01-19        NaT     NaN     0.174847
# 2003-01-20        NaT     NaN     0.174257
# 2003-01-21        NaT     NaN     0.173768
# 2003-01-22        NaT     NaN     0.173374
# 2003-01-23        NaT     NaN     0.173070
# 2003-01-24        NaT     NaN     0.172851
# 2003-01-25 2003-01-25  0.1740     0.172713
# 2003-01-26        NaT     NaN     0.172550
# 2003-01-27        NaT     NaN     0.172366
# 2003-01-28        NaT     NaN     0.172160
# 2003-01-29        NaT     NaN     0.171934
# 2003-01-30        NaT     NaN     0.171689
# 2003-01-31        NaT     NaN     0.171425
# 2003-02-01        NaT     NaN     0.171144
# 2003-02-02        NaT     NaN     0.170847
# 2003-02-03        NaT     NaN     0.170513
# 2003-02-04        NaT     NaN     0.170185
#                  Date  Doy  Station Standard             ZipCodes  Scope  \
# Date
# 2022-08-03 2022-08-03  215      266   metric  93461, 93432, 93447  daily
# 2022-08-04 2022-08-04  216      266   metric  93461, 93432, 93447  daily
# 2022-08-05 2022-08-05  217      266   metric  93461, 93432, 93447  daily
# 2022-08-06 2022-08-06  218      266   metric  93461, 93432, 93447  daily
# 2022-08-07 2022-08-07  219      266   metric  93461, 93432, 93447  daily
#
#             Tavg Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  \
# Date                                    ...
# 2022-08-03  30.9       R  38.4          ...        NaN       NaN
# 2022-08-04  24.9          33.2          ...        NaN       0.0
# 2022-08-05  22.2          31.9          ...        0.0       0.0
# 2022-08-06  20.4          31.9          ...        0.0       0.0
# 2022-08-07  22.1          34.3          ...        0.0       0.0
#
#             Tmax_diff_avg Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr  \
# Date
# 2022-08-03            NaN           NaN            NaN       NaN       NaN
# 2022-08-04            NaN           NaN            NaN       NaN       NaN
# 2022-08-05            NaN           NaN            NaN  6.948890  6.948890
# 2022-08-06            NaN           NaN            NaN  6.502509  6.502509
# 2022-08-07            NaN           NaN            NaN       NaN       NaN
#
#            ETo_CIMIS  NDVI NDVI_interp
# Date
# 2022-08-03       NaN   NaN    0.688826
# 2022-08-04      7.49   NaN    0.687752
# 2022-08-05      7.06   NaN    0.686529
# 2022-08-06      6.56   NaN    0.685158
# 2022-08-07      6.88   NaN    0.683640
#
# [5 rows x 55 columns]
# Station 267:
#                  Date    NDVI  NDVI_interp
# 2003-01-07 2003-01-07  0.1767     0.166180
# 2003-01-08 2003-01-08  0.1818     0.166311
# 2003-01-09        NaT     NaN     0.166543
# 2003-01-10        NaT     NaN     0.167074
# 2003-01-11        NaT     NaN     0.167881
# 2003-01-12        NaT     NaN     0.168940
# 2003-01-13        NaT     NaN     0.170232
# 2003-01-14        NaT     NaN     0.171739
# 2003-01-15        NaT     NaN     0.173444
# 2003-01-16 2003-01-16  0.1579     0.175333
# 2003-01-17        NaT     NaN     0.174501
# 2003-01-18        NaT     NaN     0.173995
# 2003-01-19        NaT     NaN     0.173791
# 2003-01-20        NaT     NaN     0.173871
# 2003-01-21        NaT     NaN     0.174215
# 2003-01-22        NaT     NaN     0.174807
# 2003-01-23        NaT     NaN     0.175631
# 2003-01-24        NaT     NaN     0.176672
# 2003-01-25        NaT     NaN     0.177919
# 2003-01-26        NaT     NaN     0.179170
# 2003-01-27        NaT     NaN     0.180424
# 2003-01-28        NaT     NaN     0.181682
# 2003-01-29        NaT     NaN     0.182944
# 2003-01-30        NaT     NaN     0.184208
# 2003-01-31        NaT     NaN     0.185476
# 2003-02-01        NaT     NaN     0.186746
# 2003-02-02        NaT     NaN     0.188020
# 2003-02-03        NaT     NaN     0.189305
# 2003-02-04        NaT     NaN     0.190601
# 2003-02-05        NaT     NaN     0.191908
# 2003-02-06        NaT     NaN     0.193225
# 2003-02-07        NaT     NaN     0.194552
# 2003-02-08 2003-02-08  0.1705     0.195888
# 2003-02-09 2003-02-09  0.1742     0.197554
# 2003-02-10        NaT     NaN     0.199466
#                  Date  Doy  Station Standard             ZipCodes  Scope  \
# Date
# 2022-04-27 2022-04-27  117      267   metric  96114, 96128, 96127  daily
# 2022-04-28 2022-04-28  118      267   metric  96114, 96128, 96127  daily
# 2022-04-29 2022-04-29  119      267   metric  96114, 96128, 96127  daily
# 2022-04-30 2022-04-30  120      267   metric  96114, 96128, 96127  daily
# 2022-05-01 2022-05-01  121      267   metric  96114, 96128, 96127  daily
#
#             Tavg Tavg_Qc  Tmax Tmax_Qc  ...  Tmin_diff Tdew_diff  \
# Date                                    ...
# 2022-04-27  13.9       H  18.5          ...        NaN       0.0
# 2022-04-28   6.5          13.4          ...        0.0       0.0
# 2022-04-29   7.7          18.0          ...        0.0       0.0
# 2022-04-30  12.0          19.5          ...        0.0       0.0
# 2022-05-01   8.3          16.5          ...        0.0       0.0
#
#             Tmax_diff_avg Tmin_diff_avg  Tdew_diff_avg ETo_uncor  ETo_corr  \
# Date
# 2022-04-27            NaN           NaN            NaN       NaN       NaN
# 2022-04-28            NaN           NaN            NaN  3.382529  3.382529
# 2022-04-29            NaN           NaN            NaN  4.431472  4.431472
# 2022-04-30            0.0           0.0            0.0  4.915253  4.915253
# 2022-05-01            NaN           NaN            NaN       NaN       NaN
#
#            ETo_CIMIS  NDVI NDVI_interp
# Date
# 2022-04-27       NaN   NaN    0.621746
# 2022-04-28      3.74   NaN    0.628779
# 2022-04-29      4.82   NaN    0.635547
# 2022-04-30      5.74   NaN    0.642051
# 2022-05-01      4.88   NaN    0.648291
#
# [5 rows x 55 columns]

# %%
# this list of stations has non-ETo and anomalous stations removed
#station_ids = [2, 6, 7, 12, 13, 15, 35, 39, 41, 43, 44, 47, 52, 64, 68, 70, 71, 75, 77, 78, 80, 83, 84, 87, 90, 91, 99, 104, 105, 106, 107, 113, 114, 117, 124, 125, 126, 129, 131, 140, 144, 146, 147, 150, 151, 152, 153, 157, 158, 160, 163, 165, 170, 171, 173, 174, 175, 178, 179, 181, 182, 184, 187, 191, 192, 193, 194, 195, 197, 199, 200, 202, 204, 206, 207, 208, 209, 210, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 225, 226, 227, 228, 229, 235, 236, 237, 240, 241, 242, 243, 244, 245, 247, 248, 249, 250, 251, 252, 253, 254, 256, 258, 259, 260, 261, 262, 264, 265, 266, 267, 268]

dir = '/content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/'
df_concat = pd.DataFrame()
df_month_concat = pd.DataFrame()
for id in station_ids:
  file = f'{dir}station_id{id}_cimis_daily_corr.csv'
  df = pd.read_csv(file)
  df.set_index(pd.to_datetime(df.Date), inplace=True)
  df['d_ETo'] = df['ETo_uncor'] - df['ETo_corr']

  df['d_ETo_avg'] = df['d_ETo'].groupby(pd.Grouper(axis=0, freq='M')).mean()
  df['ETo_%_diff'] = (df['ETo_uncor'] / df['ETo_corr'] - 1) * 100
  df['ETo_%_diff_monthly_avg'] = df['ETo_%_diff'].groupby(pd.Grouper(axis=0, freq='M')).mean()

  df_month = df.resample('M').last()
  df_month_concat = pd.concat([df_month_concat, df_month])

  df.to_csv(file, index=False) # saves csv with new cols
  print(file)
df_month_concat.to_csv(f'{dir}all_stations_daily_corr_MASTER.csv', index=False)
# Out:
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id2_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id6_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id7_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id12_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id13_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id15_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id35_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id39_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id41_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id43_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id44_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id47_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id52_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id64_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id68_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id70_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id71_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id75_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id77_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id78_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id80_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id83_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id84_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id87_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id90_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id91_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id99_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id104_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id105_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id106_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id107_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id113_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id114_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id117_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id124_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id125_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id126_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id129_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id131_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id140_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id144_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id146_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id147_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id150_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id151_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id152_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id153_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id157_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id158_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id160_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id163_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id165_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id170_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id171_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id173_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id174_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id175_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id178_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id179_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id181_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id182_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id184_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id187_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id191_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id192_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id193_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id194_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id195_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id197_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id199_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id200_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id202_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id204_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id206_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id207_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id208_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id209_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id210_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id212_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id213_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id214_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id215_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id216_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id217_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id218_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id219_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id220_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id221_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id222_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id223_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id225_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id226_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id227_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id228_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id229_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id235_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id236_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id237_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id240_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id241_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id242_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id243_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id244_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id245_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id247_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id248_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id249_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id250_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id251_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id252_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id253_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id254_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id256_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id258_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id259_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id260_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id261_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id262_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id264_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id265_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id266_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id267_cimis_daily_corr.csv
# /content/CIMIS/CIMIS_Project_Data/CIMIS_daily_corr_data/station_id268_cimis_daily_corr.csv

# %% [markdown]
# The following cell commits the temp-corrected files to GitHub now that all new columns have been saved to the csv files.

# %%
#the following line allows you to skip this cell for a RUN ALL execution without saving to GitHub
# %%script false --no-raise-error

if os.getcwd() != '/content/CIMIS':
  os.chdir("CIMIS")
token = userdata.get('github_token')
# !git --version
# !git config --global user.email "tretaylor@csumb.edu"
# !git config --global user.name "tr3nt-tayl0r"
# !git add -A
# !git commit -m "Saving MASTER monthly corrected file to github."
# !git remote add origin https://tr3nt-tayl0r:{token}@github.com/tr3nt-tayl0r/CIMIS.git
# !git push --set-upstream origin main
